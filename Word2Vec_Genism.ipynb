# %%
# -*- coding: utf-8 -*-

import logging

from gensim.models import word2vec

def main():

    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
    sentences = word2vec.LineSentence("../Word_Segmentation/Spur10.txt.preprocessed.segmentated")
    model = word2vec.Word2Vec(sentences, size=50)

    #保存模型，供日後使用
    model.save("word2vec.model")

    #模型讀取方式
    # model = word2vec.Word2Vec.load("your_model_name")

if __name__ == "__main__":
    main()
# Out:
# 2018-06-07 22:53:43,296 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-06-07 22:53:43,297 : INFO : collecting all words and their counts
# 2018-06-07 22:53:43,298 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-06-07 22:53:43,379 : INFO : PROGRESS: at sentence #10000, processed 100681 words, keeping 13023 word types
# 2018-06-07 22:53:43,436 : INFO : PROGRESS: at sentence #20000, processed 209494 words, keeping 19944 word types
# 2018-06-07 22:53:43,495 : INFO : PROGRESS: at sentence #30000, processed 309745 words, keeping 25776 word types
# 2018-06-07 22:53:43,556 : INFO : PROGRESS: at sentence #40000, processed 416433 words, keeping 30741 word types
# 2018-06-07 22:53:43,622 : INFO : PROGRESS: at sentence #50000, processed 542813 words, keeping 32038 word types
# 2018-06-07 22:53:43,687 : INFO : PROGRESS: at sentence #60000, processed 681262 words, keeping 33305 word types
# 2018-06-07 22:53:43,755 : INFO : PROGRESS: at sentence #70000, processed 811565 words, keeping 34368 word types
# 2018-06-07 22:53:43,823 : INFO : PROGRESS: at sentence #80000, processed 939190 words, keeping 35521 word types
# 2018-06-07 22:53:43,920 : INFO : PROGRESS: at sentence #90000, processed 1069742 words, keeping 36304 word types
# 2018-06-07 22:53:43,972 : INFO : PROGRESS: at sentence #100000, processed 1148800 words, keeping 38431 word types
# 2018-06-07 22:53:44,012 : INFO : PROGRESS: at sentence #110000, processed 1215329 words, keeping 41273 word types
# 2018-06-07 22:53:44,077 : INFO : PROGRESS: at sentence #120000, processed 1280822 words, keeping 43714 word types
# 2018-06-07 22:53:44,152 : INFO : PROGRESS: at sentence #130000, processed 1345511 words, keeping 45954 word types
# 2018-06-07 22:53:44,230 : INFO : PROGRESS: at sentence #140000, processed 1408897 words, keeping 48131 word types
# 2018-06-07 22:53:44,296 : INFO : PROGRESS: at sentence #150000, processed 1500409 words, keeping 50153 word types
# 2018-06-07 22:53:44,354 : INFO : PROGRESS: at sentence #160000, processed 1589881 words, keeping 53148 word types
# 2018-06-07 22:53:44,420 : INFO : PROGRESS: at sentence #170000, processed 1671993 words, keeping 55702 word types
# 2018-06-07 22:53:44,527 : INFO : PROGRESS: at sentence #180000, processed 1762009 words, keeping 58524 word types
# 2018-06-07 22:53:44,611 : INFO : PROGRESS: at sentence #190000, processed 1864551 words, keeping 61930 word types
# 2018-06-07 22:53:44,698 : INFO : PROGRESS: at sentence #200000, processed 1954801 words, keeping 65531 word types
# 2018-06-07 22:53:44,761 : INFO : PROGRESS: at sentence #210000, processed 2039497 words, keeping 68178 word types
# 2018-06-07 22:53:44,821 : INFO : PROGRESS: at sentence #220000, processed 2128098 words, keeping 70689 word types
# 2018-06-07 22:53:44,902 : INFO : PROGRESS: at sentence #230000, processed 2214654 words, keeping 73243 word types
# 2018-06-07 22:53:44,967 : INFO : PROGRESS: at sentence #240000, processed 2302351 words, keeping 75892 word types
# 2018-06-07 22:53:45,037 : INFO : PROGRESS: at sentence #250000, processed 2389215 words, keeping 77974 word types
# 2018-06-07 22:53:45,115 : INFO : PROGRESS: at sentence #260000, processed 2482125 words, keeping 80444 word types
# 2018-06-07 22:53:45,178 : INFO : PROGRESS: at sentence #270000, processed 2567818 words, keeping 82443 word types
# 2018-06-07 22:53:45,237 : INFO : PROGRESS: at sentence #280000, processed 2658799 words, keeping 84474 word types
# 2018-06-07 22:53:45,299 : INFO : PROGRESS: at sentence #290000, processed 2753199 words, keeping 86619 word types
# 2018-06-07 22:53:45,358 : INFO : PROGRESS: at sentence #300000, processed 2838757 words, keeping 88400 word types
# 2018-06-07 22:53:45,401 : INFO : collected 89927 word types from a corpus of 2904250 raw words and 307087 sentences
# 2018-06-07 22:53:45,401 : INFO : Loading a fresh vocabulary
# 2018-06-07 22:53:45,520 : INFO : min_count=5 retains 21584 unique words (24% of original 89927, drops 68343)
# 2018-06-07 22:53:45,521 : INFO : min_count=5 leaves 2797839 word corpus (96% of original 2904250, drops 106411)
# 2018-06-07 22:53:45,640 : INFO : deleting the raw counts dictionary of 89927 items
# 2018-06-07 22:53:45,647 : INFO : sample=0.001 downsamples 54 most-common words
# 2018-06-07 22:53:45,650 : INFO : downsampling leaves estimated 2265835 word corpus (81.0% of prior 2797839)
# 2018-06-07 22:53:45,748 : INFO : estimated required memory for 21584 words and 50 dimensions: 19425600 bytes
# 2018-06-07 22:53:45,749 : INFO : resetting layer weights
# 2018-06-07 22:53:46,021 : INFO : training model with 3 workers on 21584 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-06-07 22:53:47,034 : INFO : EPOCH 1 - PROGRESS: at 14.59% examples, 374920 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:53:48,034 : INFO : EPOCH 1 - PROGRESS: at 39.46% examples, 467259 words/s, in_qsize 0, out_qsize 0
# 2018-06-07 22:53:49,040 : INFO : EPOCH 1 - PROGRESS: at 63.75% examples, 481385 words/s, in_qsize 0, out_qsize 0
# 2018-06-07 22:53:50,061 : INFO : EPOCH 1 - PROGRESS: at 90.82% examples, 509566 words/s, in_qsize 0, out_qsize 1
# 2018-06-07 22:53:50,378 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-07 22:53:50,386 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-07 22:53:50,395 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-07 22:53:50,397 : INFO : EPOCH - 1 : training on 2904250 raw words (2265190 effective words) took 4.4s, 518509 effective words/s
# 2018-06-07 22:53:51,425 : INFO : EPOCH 2 - PROGRESS: at 24.10% examples, 615302 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:53:52,426 : INFO : EPOCH 2 - PROGRESS: at 55.14% examples, 617467 words/s, in_qsize 1, out_qsize 0
# 2018-06-07 22:53:53,484 : INFO : EPOCH 2 - PROGRESS: at 84.53% examples, 622161 words/s, in_qsize 2, out_qsize 3
# 2018-06-07 22:53:53,938 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-07 22:53:53,941 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-07 22:53:53,946 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-07 22:53:53,947 : INFO : EPOCH - 2 : training on 2904250 raw words (2265610 effective words) took 3.5s, 640086 effective words/s
# 2018-06-07 22:53:54,963 : INFO : EPOCH 3 - PROGRESS: at 24.78% examples, 638022 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:53:55,966 : INFO : EPOCH 3 - PROGRESS: at 54.32% examples, 610379 words/s, in_qsize 4, out_qsize 0
# 2018-06-07 22:53:56,977 : INFO : EPOCH 3 - PROGRESS: at 86.09% examples, 643746 words/s, in_qsize 3, out_qsize 2
# 2018-06-07 22:53:57,793 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-07 22:53:57,796 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-07 22:53:57,799 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-07 22:53:57,800 : INFO : EPOCH - 3 : training on 2904250 raw words (2265476 effective words) took 3.8s, 588748 effective words/s
# 2018-06-07 22:53:58,818 : INFO : EPOCH 4 - PROGRESS: at 18.43% examples, 475374 words/s, in_qsize 0, out_qsize 0
# 2018-06-07 22:53:59,821 : INFO : EPOCH 4 - PROGRESS: at 40.48% examples, 472704 words/s, in_qsize 0, out_qsize 0
# 2018-06-07 22:54:00,826 : INFO : EPOCH 4 - PROGRESS: at 65.63% examples, 493032 words/s, in_qsize 0, out_qsize 0
# 2018-06-07 22:54:01,839 : INFO : EPOCH 4 - PROGRESS: at 93.54% examples, 525522 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:54:01,992 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-07 22:54:01,996 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-07 22:54:01,997 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-07 22:54:01,998 : INFO : EPOCH - 4 : training on 2904250 raw words (2264913 effective words) took 4.2s, 540018 effective words/s
# 2018-06-07 22:54:03,013 : INFO : EPOCH 5 - PROGRESS: at 26.94% examples, 694715 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:54:04,018 : INFO : EPOCH 5 - PROGRESS: at 61.37% examples, 691550 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:54:05,028 : INFO : EPOCH 5 - PROGRESS: at 86.80% examples, 649057 words/s, in_qsize 5, out_qsize 0
# 2018-06-07 22:54:05,475 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-07 22:54:05,490 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-07 22:54:05,492 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-07 22:54:05,494 : INFO : EPOCH - 5 : training on 2904250 raw words (2265448 effective words) took 3.5s, 648949 effective words/s
# 2018-06-07 22:54:05,495 : INFO : training on a 14521250 raw words (11326637 effective words) took 19.5s, 581697 effective words/s
# 2018-06-07 22:54:05,496 : INFO : saving Word2Vec object under word2vec.model, separately None
# 2018-06-07 22:54:05,497 : INFO : not storing attribute vectors_norm
# 2018-06-07 22:54:05,499 : INFO : not storing attribute cum_table
# 2018-06-07 22:54:05,660 : INFO : saved word2vec.model

# %%
from gensim import models

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
model = models.Word2Vec.load('word2vec.model')
# Out:
# 2018-06-07 22:54:05,678 : INFO : loading Word2Vec object from word2vec.model
# 2018-06-07 22:54:05,783 : INFO : loading wv recursively from word2vec.model.wv.* with mmap=None
# 2018-06-07 22:54:05,784 : INFO : setting ignored attribute vectors_norm to None
# 2018-06-07 22:54:05,784 : INFO : loading vocabulary recursively from word2vec.model.vocabulary.* with mmap=None
# 2018-06-07 22:54:05,785 : INFO : loading trainables recursively from word2vec.model.trainables.* with mmap=None
# 2018-06-07 22:54:05,787 : INFO : setting ignored attribute cum_table to None
# 2018-06-07 22:54:05,790 : INFO : loaded word2vec.model

# %%
model.wv.vocab
# Out:
# {'標題': <gensim.models.keyedvectors.Vocab at 0x1086f14a8>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1086f1908>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x1086f1940>,
#  '情報': <gensim.models.keyedvectors.Vocab at 0x1086f1828>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x1086f1898>,
#  'John': <gensim.models.keyedvectors.Vocab at 0x1086f1a20>,
#  'Wall': <gensim.models.keyedvectors.Vocab at 0x1086f19b0>,
#  '拒絕': <gensim.models.keyedvectors.Vocab at 0x1086f1b70>,
#  '巫師': <gensim.models.keyedvectors.Vocab at 0x1086f1e80>,
#  '1.68': <gensim.models.keyedvectors.Vocab at 0x1086f1b38>,
#  '億': <gensim.models.keyedvectors.Vocab at 0x10c411d68>,
#  '合同': <gensim.models.keyedvectors.Vocab at 0x10c411c18>,
#  '馬刺': <gensim.models.keyedvectors.Vocab at 0x10c4114e0>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x10c4111d0>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x10c4116d8>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x10c4116a0>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x10c411588>,
#  '動作': <gensim.models.keyedvectors.Vocab at 0x10c411278>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x10c411c88>,
#  '現役': <gensim.models.keyedvectors.Vocab at 0x10c411470>,
#  '最快': <gensim.models.keyedvectors.Vocab at 0x10c411438>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x10c4117b8>,
#  '後衛': <gensim.models.keyedvectors.Vocab at 0x10c411978>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x10c411d30>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x10c411b00>,
#  '當然': <gensim.models.keyedvectors.Vocab at 0x10c4112b0>,
#  '巔峰': <gensim.models.keyedvectors.Vocab at 0x10c411710>,
#  'Tony': <gensim.models.keyedvectors.Vocab at 0x10c4117f0>,
#  'Parker': <gensim.models.keyedvectors.Vocab at 0x10c411908>,
#  '幾分': <gensim.models.keyedvectors.Vocab at 0x10c411b38>,
#  '相似': <gensim.models.keyedvectors.Vocab at 0x10c411b70>,
#  '根據': <gensim.models.keyedvectors.Vocab at 0x10c411048>,
#  '老將': <gensim.models.keyedvectors.Vocab at 0x10c411748>,
#  '條款': <gensim.models.keyedvectors.Vocab at 0x10c4119e8>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x10c4110f0>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x10c4113c8>,
#  '今夏': <gensim.models.keyedvectors.Vocab at 0x10c411518>,
#  '提前': <gensim.models.keyedvectors.Vocab at 0x10c4112e8>,
#  '續約': <gensim.models.keyedvectors.Vocab at 0x10c411198>,
#  '為': <gensim.models.keyedvectors.Vocab at 0x10c411160>,
#  '準備': <gensim.models.keyedvectors.Vocab at 0x10c4115f8>,
#  '一份': <gensim.models.keyedvectors.Vocab at 0x10c411ef0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x10c411f98>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x10c411eb8>,
#  '說': <gensim.models.keyedvectors.Vocab at 0x10c411ac8>,
#  '這個': <gensim.models.keyedvectors.Vocab at 0x10c411550>,
#  '價位': <gensim.models.keyedvectors.Vocab at 0x10c411cc0>,
#  '真不錯': <gensim.models.keyedvectors.Vocab at 0x10c4114a8>,
#  '可是': <gensim.models.keyedvectors.Vocab at 0x10c411e48>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x10c411630>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x10c411e80>,
#  '傳': <gensim.models.keyedvectors.Vocab at 0x10c411320>,
#  'Chris': <gensim.models.keyedvectors.Vocab at 0x10c411dd8>,
#  'Paul': <gensim.models.keyedvectors.Vocab at 0x10c411240>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x10c411400>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x10c411ba8>,
#  '時候': <gensim.models.keyedvectors.Vocab at 0x10c411da0>,
#  '這種': <gensim.models.keyedvectors.Vocab at 0x10c411c50>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x10c411a90>,
#  '殺': <gensim.models.keyedvectors.Vocab at 0x10c411780>,
#  '出來': <gensim.models.keyedvectors.Vocab at 0x10c411a58>,
#  '一個': <gensim.models.keyedvectors.Vocab at 0x10c411cf8>,
#  '記者': <gensim.models.keyedvectors.Vocab at 0x10c050048>,
#  '曾': <gensim.models.keyedvectors.Vocab at 0x10c050c88>,
#  '爆': <gensim.models.keyedvectors.Vocab at 0x10c050f98>,
#  '料': <gensim.models.keyedvectors.Vocab at 0x10c050400>,
#  '主教練': <gensim.models.keyedvectors.Vocab at 0x10c050d68>,
#  'Gregg': <gensim.models.keyedvectors.Vocab at 0x10c050518>,
#  'Popovich': <gensim.models.keyedvectors.Vocab at 0x10c0503c8>,
#  '電話': <gensim.models.keyedvectors.Vocab at 0x10c0500f0>,
#  '記錄': <gensim.models.keyedvectors.Vocab at 0x10c050a90>,
#  '不過': <gensim.models.keyedvectors.Vocab at 0x10c050f60>,
#  '討論': <gensim.models.keyedvectors.Vocab at 0x10c050080>,
#  '什麼': <gensim.models.keyedvectors.Vocab at 0x10c0504e0>,
#  '還': <gensim.models.keyedvectors.Vocab at 0x10c0502e8>,
#  '不得而知': <gensim.models.keyedvectors.Vocab at 0x10c0500b8>,
#  '這': <gensim.models.keyedvectors.Vocab at 0x10c050748>,
#  '種': <gensim.models.keyedvectors.Vocab at 0x10c050320>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x10c050a20>,
#  '很難': <gensim.models.keyedvectors.Vocab at 0x10c050550>,
#  '不讓': <gensim.models.keyedvectors.Vocab at 0x10c050898>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x10c0501d0>,
#  '揣測': <gensim.models.keyedvectors.Vocab at 0x10c050940>,
#  '有點': <gensim.models.keyedvectors.Vocab at 0x10c050710>,
#  '年輕': <gensim.models.keyedvectors.Vocab at 0x10c050390>,
#  '意思': <gensim.models.keyedvectors.Vocab at 0x10c050470>,
#  '傳球': <gensim.models.keyedvectors.Vocab at 0x10c050358>,
#  '第一': <gensim.models.keyedvectors.Vocab at 0x10c0502b0>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x10c050630>,
#  '突破': <gensim.models.keyedvectors.Vocab at 0x10c050828>,
#  '能力': <gensim.models.keyedvectors.Vocab at 0x10c050198>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x10c0506a0>,
#  '很強': <gensim.models.keyedvectors.Vocab at 0x10c0504a8>,
#  '還有': <gensim.models.keyedvectors.Vocab at 0x10c050ef0>,
#  '不錯': <gensim.models.keyedvectors.Vocab at 0x10c050a58>,
#  '投籃': <gensim.models.keyedvectors.Vocab at 0x10c050128>,
#  '關': <gensim.models.keyedvectors.Vocab at 0x10c050c18>,
#  '鍵': <gensim.models.keyedvectors.Vocab at 0x10c050588>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x10c050da0>,
#  '身體': <gensim.models.keyedvectors.Vocab at 0x10c050fd0>,
#  '天賦': <gensim.models.keyedvectors.Vocab at 0x10c050eb8>,
#  '素質': <gensim.models.keyedvectors.Vocab at 0x10c050278>,
#  '非常': <gensim.models.keyedvectors.Vocab at 0x10c050ba8>,
#  '爆炸': <gensim.models.keyedvectors.Vocab at 0x10c050b38>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x10c0509e8>,
#  '加強': <gensim.models.keyedvectors.Vocab at 0x10c050e48>,
#  '版本': <gensim.models.keyedvectors.Vocab at 0x10c0507f0>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x10c0505c0>,
#  '確實': <gensim.models.keyedvectors.Vocab at 0x10c050ac8>,
#  '當年': <gensim.models.keyedvectors.Vocab at 0x10c050f28>,
#  '有點像': <gensim.models.keyedvectors.Vocab at 0x10c0508d0>,
#  '難怪': <gensim.models.keyedvectors.Vocab at 0x10c050e10>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x10c050e80>,
#  '一旦': <gensim.models.keyedvectors.Vocab at 0x10c050cc0>,
#  '退役': <gensim.models.keyedvectors.Vocab at 0x10c050b00>,
#  '沒有': <gensim.models.keyedvectors.Vocab at 0x10c0505f8>,
#  '關係': <gensim.models.keyedvectors.Vocab at 0x10c050be0>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x10c050c50>,
#  '能夠': <gensim.models.keyedvectors.Vocab at 0x10c050dd8>,
#  '拿下': <gensim.models.keyedvectors.Vocab at 0x10c0507b8>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x10c050d30>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x10c050160>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x10c0506d8>,
#  '恐怖': <gensim.models.keyedvectors.Vocab at 0x10c050780>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x10c050240>,
#  'LaMarcus': <gensim.models.keyedvectors.Vocab at 0x10c050208>,
#  'Aldridge': <gensim.models.keyedvectors.Vocab at 0x10c050b70>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x10c050978>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x10bcf4f60>,
#  '處理': <gensim.models.keyedvectors.Vocab at 0x10bcf4fd0>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x10bcf4f98>,
#  '因為': <gensim.models.keyedvectors.Vocab at 0x108701588>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x106cc5518>,
#  '加盟': <gensim.models.keyedvectors.Vocab at 0x1086377f0>,
#  '還能': <gensim.models.keyedvectors.Vocab at 0x108637940>,
#  '西區': <gensim.models.keyedvectors.Vocab at 0x108637ef0>,
#  '稱王': <gensim.models.keyedvectors.Vocab at 0x108637e48>,
#  '嗎': <gensim.models.keyedvectors.Vocab at 0x108637be0>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x10cffdbe0>,
#  '來源': <gensim.models.keyedvectors.Vocab at 0x10cffdb70>,
#  'Haters': <gensim.models.keyedvectors.Vocab at 0x10cffdb00>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x10cffdba8>,
#  '黑特': <gensim.models.keyedvectors.Vocab at 0x10cffdda0>,
#  '籃球': <gensim.models.keyedvectors.Vocab at 0x10cffdc50>,
#  'NBA': <gensim.models.keyedvectors.Vocab at 0x10cffdc18>,
#  '新聞': <gensim.models.keyedvectors.Vocab at 0x10cffddd8>,
#  '影片': <gensim.models.keyedvectors.Vocab at 0x10cffd2b0>,
#  '圖片': <gensim.models.keyedvectors.Vocab at 0x10cffdcf8>,
#  '分享': <gensim.models.keyedvectors.Vocab at 0x10cffde10>,
#  '社區': <gensim.models.keyedvectors.Vocab at 0x10cffdcc0>,
#  'PS': <gensim.models.keyedvectors.Vocab at 0x10cffd438>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x10cffdef0>,
#  '知道': <gensim.models.keyedvectors.Vocab at 0x10cffd208>,
#  '真的假': <gensim.models.keyedvectors.Vocab at 0x10cffd198>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x10cffdf28>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x10cffd2e8>,
#  '相信': <gensim.models.keyedvectors.Vocab at 0x10cffd160>,
#  '一切': <gensim.models.keyedvectors.Vocab at 0x10cffd240>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x10cffd390>,
#  '不會': <gensim.models.keyedvectors.Vocab at 0x10cffdeb8>,
#  '發生': <gensim.models.keyedvectors.Vocab at 0x10cffdf60>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x10cffd0b8>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x10cffd1d0>,
#  '還是': <gensim.models.keyedvectors.Vocab at 0x10cffd278>,
#  '會': <gensim.models.keyedvectors.Vocab at 0x10cffdd68>,
#  '乖乖': <gensim.models.keyedvectors.Vocab at 0x10cffd320>,
#  '簽約': <gensim.models.keyedvectors.Vocab at 0x10cffd400>,
#  'XDD': <gensim.models.keyedvectors.Vocab at 0x10cffdf98>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x10cffd828>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x10cffdd30>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x10cffd7b8>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x10cffd860>,
#  '07': <gensim.models.keyedvectors.Vocab at 0x10cffd7f0>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x10cffd940>,
#  '想太多': <gensim.models.keyedvectors.Vocab at 0x10cffd9e8>,
#  'XD': <gensim.models.keyedvectors.Vocab at 0x10cffdac8>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x10cffda58>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x10cffd898>,
#  '確定': <gensim.models.keyedvectors.Vocab at 0x10cffd748>,
#  '東區': <gensim.models.keyedvectors.Vocab at 0x10cffda20>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x10cffd518>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x10cffda90>,
#  'beal': <gensim.models.keyedvectors.Vocab at 0x10cffd5c0>,
#  '真的': <gensim.models.keyedvectors.Vocab at 0x10cffd588>,
#  '不合': <gensim.models.keyedvectors.Vocab at 0x10cffd550>,
#  '電梯': <gensim.models.keyedvectors.Vocab at 0x10cffd3c8>,
#  '繼續': <gensim.models.keyedvectors.Vocab at 0x10cffd668>,
#  '向下': <gensim.models.keyedvectors.Vocab at 0x10cffd6a0>,
#  '神經病': <gensim.models.keyedvectors.Vocab at 0x10cffd5f8>,
#  '快': <gensim.models.keyedvectors.Vocab at 0x10cffdb38>,
#  '清空': <gensim.models.keyedvectors.Vocab at 0x10cffd710>,
#  '來來來': <gensim.models.keyedvectors.Vocab at 0x10cffd9b0>,
#  '來': <gensim.models.keyedvectors.Vocab at 0x10cffd358>,
#  '趕快': <gensim.models.keyedvectors.Vocab at 0x10cffd6d8>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x10cffd4a8>,
#  '降薪': <gensim.models.keyedvectors.Vocab at 0x10cffd630>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x10cffd470>,
#  '組大團': <gensim.models.keyedvectors.Vocab at 0x10cffd780>,
#  '76': <gensim.models.keyedvectors.Vocab at 0x10cff8d30>,
#  '應該': <gensim.models.keyedvectors.Vocab at 0x10cff8cf8>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x10cff8cc0>,
#  '發文': <gensim.models.keyedvectors.Vocab at 0x10cff8c88>,
#  '太': <gensim.models.keyedvectors.Vocab at 0x10cff8c50>,
#  '舒適': <gensim.models.keyedvectors.Vocab at 0x10cff8c18>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x10cff8be0>,
#  '啊': <gensim.models.keyedvectors.Vocab at 0x10cff8ba8>,
#  '誇張': <gensim.models.keyedvectors.Vocab at 0x10cff8b70>,
#  '德州': <gensim.models.keyedvectors.Vocab at 0x10cff8b38>,
#  '免州稅': <gensim.models.keyedvectors.Vocab at 0x10cff8b00>,
#  '就算': <gensim.models.keyedvectors.Vocab at 0x10cff8ac8>,
#  '報價': <gensim.models.keyedvectors.Vocab at 0x10cff8a90>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x10cff8a58>,
#  '原先': <gensim.models.keyedvectors.Vocab at 0x10cff8a20>,
#  '華盛頓': <gensim.models.keyedvectors.Vocab at 0x10cff89e8>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x10cff89b0>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x10cff8978>,
#  '抬價': <gensim.models.keyedvectors.Vocab at 0x10cff8940>,
#  '專武': <gensim.models.keyedvectors.Vocab at 0x10cff8908>,
#  'Hill': <gensim.models.keyedvectors.Vocab at 0x10cff8898>,
#  '吃不下': <gensim.models.keyedvectors.Vocab at 0x10cff8860>,
#  '吃': <gensim.models.keyedvectors.Vocab at 0x10cff8828>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x10cff87f0>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x10cff87b8>,
#  '超': <gensim.models.keyedvectors.Vocab at 0x10cff8780>,
#  '圈': <gensim.models.keyedvectors.Vocab at 0x10cff8748>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x10cff8710>,
#  'KD': <gensim.models.keyedvectors.Vocab at 0x10cff86a0>,
#  '2500': <gensim.models.keyedvectors.Vocab at 0x10cff8630>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x10cff85f8>,
#  '2000': <gensim.models.keyedvectors.Vocab at 0x10cff8588>,
#  '合理': <gensim.models.keyedvectors.Vocab at 0x10cff8550>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x10cff8518>,
#  '擠': <gensim.models.keyedvectors.Vocab at 0x10cff84e0>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x10cff8470>,
#  '啦': <gensim.models.keyedvectors.Vocab at 0x10cff8438>,
#  '那個': <gensim.models.keyedvectors.Vocab at 0x10cff8400>,
#  '錢': <gensim.models.keyedvectors.Vocab at 0x10cff83c8>,
#  '早就': <gensim.models.keyedvectors.Vocab at 0x10cff8390>,
#  '簽': <gensim.models.keyedvectors.Vocab at 0x10cff8358>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x10cff8320>,
#  '明星': <gensim.models.keyedvectors.Vocab at 0x10cff82e8>,
#  '派': <gensim.models.keyedvectors.Vocab at 0x10cff82b0>,
#  '誰': <gensim.models.keyedvectors.Vocab at 0x10cff8278>,
#  '最好': <gensim.models.keyedvectors.Vocab at 0x10cff8240>,
#  'XDDDD': <gensim.models.keyedvectors.Vocab at 0x10cff81d0>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x10cff8198>,
#  '每個': <gensim.models.keyedvectors.Vocab at 0x10cff8160>,
#  '毫無': <gensim.models.keyedvectors.Vocab at 0x10cff8128>,
#  '下限': <gensim.models.keyedvectors.Vocab at 0x10cff80f0>,
#  '這篇': <gensim.models.keyedvectors.Vocab at 0x10cff80b8>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x10cff8080>,
#  '賽季': <gensim.models.keyedvectors.Vocab at 0x10cff8048>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x10cff8eb8>,
#  '可愛': <gensim.models.keyedvectors.Vocab at 0x10cff8da0>,
#  '歐': <gensim.models.keyedvectors.Vocab at 0x10cff8fd0>,
#  '雞雞': <gensim.models.keyedvectors.Vocab at 0x10cff8e48>,
#  '牆': <gensim.models.keyedvectors.Vocab at 0x107f5d6a0>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x107f5d6d8>,
#  '保羅': <gensim.models.keyedvectors.Vocab at 0x107f5d2b0>,
#  '鬍子': <gensim.models.keyedvectors.Vocab at 0x10bd0c5c0>,
#  '米爾': <gensim.models.keyedvectors.Vocab at 0x10bd0c6a0>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x10bd0c470>,
#  '裡都': <gensim.models.keyedvectors.Vocab at 0x10bd0c7b8>,
#  '可惜': <gensim.models.keyedvectors.Vocab at 0x10bd0c4a8>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x10bd0c940>,
#  '夢裡': <gensim.models.keyedvectors.Vocab at 0x10bd0c2b0>,
#  'CP3': <gensim.models.keyedvectors.Vocab at 0x10bd0cef0>,
#  '換成': <gensim.models.keyedvectors.Vocab at 0x10bd0c668>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x10bd0c4e0>,
#  '問題': <gensim.models.keyedvectors.Vocab at 0x10bd0c5f8>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x10bd0cba8>,
#  '沒': <gensim.models.keyedvectors.Vocab at 0x10bd0cdd8>,
#  '空間': <gensim.models.keyedvectors.Vocab at 0x10bd0c358>,
#  '這約': <gensim.models.keyedvectors.Vocab at 0x10bd0ccf8>,
#  '咖哩': <gensim.models.keyedvectors.Vocab at 0x10bd0c898>,
#  '還大': <gensim.models.keyedvectors.Vocab at 0x10bd0c2e8>,
#  '居然': <gensim.models.keyedvectors.Vocab at 0x10bd0ce10>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x10bd0cda0>,
#  '開': <gensim.models.keyedvectors.Vocab at 0x10bd0c6d8>,
#  '不了': <gensim.models.keyedvectors.Vocab at 0x10bd0c780>,
#  '更': <gensim.models.keyedvectors.Vocab at 0x10bd0c710>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x10bd0c3c8>,
#  '勿': <gensim.models.keyedvectors.Vocab at 0x10bd0cf60>,
#  '幻想': <gensim.models.keyedvectors.Vocab at 0x10bd0cf28>,
#  '....': <gensim.models.keyedvectors.Vocab at 0x10bd0c588>,
#  '除非': <gensim.models.keyedvectors.Vocab at 0x10bd0c9b0>,
#  '清掉': <gensim.models.keyedvectors.Vocab at 0x10bd0c518>,
#  'AGG': <gensim.models.keyedvectors.Vocab at 0x10bd0cf98>,
#  '不然': <gensim.models.keyedvectors.Vocab at 0x10bd0c630>,
#  '作夢': <gensim.models.keyedvectors.Vocab at 0x10bd0ccc0>,
#  '謝謝': <gensim.models.keyedvectors.Vocab at 0x10bd0c438>,
#  '要學': <gensim.models.keyedvectors.Vocab at 0x10bd0c978>,
#  '加': <gensim.models.keyedvectors.Vocab at 0x10bd0c9e8>,
#  '然後': <gensim.models.keyedvectors.Vocab at 0x10bd0c550>,
#  '一拼': <gensim.models.keyedvectors.Vocab at 0x10bd0cc88>,
#  '換': <gensim.models.keyedvectors.Vocab at 0x10bd0c860>,
#  '平均': <gensim.models.keyedvectors.Vocab at 0x10bd0c908>,
#  'curry': <gensim.models.keyedvectors.Vocab at 0x10bd0cd68>,
#  '還高': <gensim.models.keyedvectors.Vocab at 0x10bd0c198>,
#  '欸': <gensim.models.keyedvectors.Vocab at 0x10bd0cc18>,
#  '摳': <gensim.models.keyedvectors.Vocab at 0x10bd0ca90>,
#  '零': <gensim.models.keyedvectors.Vocab at 0x10bd0c0b8>,
#  '感覺': <gensim.models.keyedvectors.Vocab at 0x10bd0c7f0>,
#  '比較': <gensim.models.keyedvectors.Vocab at 0x10bd0cb00>,
#  '像是': <gensim.models.keyedvectors.Vocab at 0x10bd0c828>,
#  '拿': <gensim.models.keyedvectors.Vocab at 0x10bd0ca20>,
#  '去換': <gensim.models.keyedvectors.Vocab at 0x10bd0ce80>,
#  '看起來': <gensim.models.keyedvectors.Vocab at 0x10bd0ce48>,
#  '像': <gensim.models.keyedvectors.Vocab at 0x10bd0c160>,
#  '對岸': <gensim.models.keyedvectors.Vocab at 0x10bd0c278>,
#  '文': <gensim.models.keyedvectors.Vocab at 0x10bd0cb38>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x10bd0c400>,
#  '隊': <gensim.models.keyedvectors.Vocab at 0x10bd0cd30>,
#  '鳥權': <gensim.models.keyedvectors.Vocab at 0x10bd0c748>,
#  '也給': <gensim.models.keyedvectors.Vocab at 0x10bd0c8d0>,
#  '不到': <gensim.models.keyedvectors.Vocab at 0x10bd0c080>,
#  '價碼': <gensim.models.keyedvectors.Vocab at 0x10bd0c390>,
#  '下季': <gensim.models.keyedvectors.Vocab at 0x10bd0c0f0>,
#  '賽': <gensim.models.keyedvectors.Vocab at 0x10bd0cac8>,
#  '靶子': <gensim.models.keyedvectors.Vocab at 0x10bd0c240>,
#  '網站': <gensim.models.keyedvectors.Vocab at 0x10bd0cfd0>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x10bd0ca58>,
#  '假新聞': <gensim.models.keyedvectors.Vocab at 0x10bd0cb70>,
#  '爆料': <gensim.models.keyedvectors.Vocab at 0x10bd0c320>,
#  '嗯': <gensim.models.keyedvectors.Vocab at 0x10bd0cc50>,
#  '......': <gensim.models.keyedvectors.Vocab at 0x10c5f9208>,
#  '假': <gensim.models.keyedvectors.Vocab at 0x10c5f9898>,
#  '議題': <gensim.models.keyedvectors.Vocab at 0x10c5f9400>,
#  '佩服': <gensim.models.keyedvectors.Vocab at 0x10c5f9c18>,
#  '強哥': <gensim.models.keyedvectors.Vocab at 0x10c5f9ef0>,
#  '這時': <gensim.models.keyedvectors.Vocab at 0x10c5f9e80>,
#  '代': <gensim.models.keyedvectors.Vocab at 0x10c5f9668>,
#  '不受': <gensim.models.keyedvectors.Vocab at 0x10c5f9f98>,
#  '誘惑': <gensim.models.keyedvectors.Vocab at 0x10c5f9da0>,
#  '太少': <gensim.models.keyedvectors.Vocab at 0x10c5f9be0>,
#  '冠軍': <gensim.models.keyedvectors.Vocab at 0x10c5f9780>,
#  '肥約': <gensim.models.keyedvectors.Vocab at 0x10c5f9978>,
#  '重要': <gensim.models.keyedvectors.Vocab at 0x10c5f96d8>,
#  '別傻了': <gensim.models.keyedvectors.Vocab at 0x10c5f9eb8>,
#  '老闆': <gensim.models.keyedvectors.Vocab at 0x10c5f9dd8>,
#  '球員': <gensim.models.keyedvectors.Vocab at 0x10c5f97f0>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x10c5f9d68>,
#  '26': <gensim.models.keyedvectors.Vocab at 0x10c5f9b70>,
#  '這份': <gensim.models.keyedvectors.Vocab at 0x10c5f95f8>,
#  '五年': <gensim.models.keyedvectors.Vocab at 0x10c5f9cf8>,
#  '已經': <gensim.models.keyedvectors.Vocab at 0x10c5f94e0>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x10c5f99b0>,
#  '約': <gensim.models.keyedvectors.Vocab at 0x10c5f9c88>,
#  '根本無法': <gensim.models.keyedvectors.Vocab at 0x10c5f9470>,
#  '跟進': <gensim.models.keyedvectors.Vocab at 0x10c5f9a90>,
#  '這也能': <gensim.models.keyedvectors.Vocab at 0x10c5f9550>,
#  '加入': <gensim.models.keyedvectors.Vocab at 0x10c5f9320>,
#  '上賽季': <gensim.models.keyedvectors.Vocab at 0x10c5f9588>,
#  '新人': <gensim.models.keyedvectors.Vocab at 0x10c5f9240>,
#  '莫瑞': <gensim.models.keyedvectors.Vocab at 0x10c5f93c8>,
#  '這味': <gensim.models.keyedvectors.Vocab at 0x10c5f9198>,
#  '作文': <gensim.models.keyedvectors.Vocab at 0x10c5f9860>,
#  '豐富': <gensim.models.keyedvectors.Vocab at 0x10c5f92b0>,
#  '唷': <gensim.models.keyedvectors.Vocab at 0x10c5f9080>,
#  '林': <gensim.models.keyedvectors.Vocab at 0x10c5f90b8>,
#  '手下敗將': <gensim.models.keyedvectors.Vocab at 0x10c5f9390>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x10c5f9a58>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x10c5f91d0>,
#  '想要': <gensim.models.keyedvectors.Vocab at 0x10c5f9ba8>,
#  '別隊': <gensim.models.keyedvectors.Vocab at 0x10c5f9358>,
#  '組團': <gensim.models.keyedvectors.Vocab at 0x10c5f9c50>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x10c5f9128>,
#  '四千': <gensim.models.keyedvectors.Vocab at 0x10c5f9828>,
#  '領': <gensim.models.keyedvectors.Vocab at 0x10c5f9f60>,
#  '兩千': <gensim.models.keyedvectors.Vocab at 0x10c5f92e8>,
#  '籌碼': <gensim.models.keyedvectors.Vocab at 0x10c5f9160>,
#  '去簽': <gensim.models.keyedvectors.Vocab at 0x10c5f9048>,
#  '要錢': <gensim.models.keyedvectors.Vocab at 0x10c5f96a0>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x10c5f9b38>,
#  '能給': <gensim.models.keyedvectors.Vocab at 0x10c5f97b8>,
#  '最多': <gensim.models.keyedvectors.Vocab at 0x10c5f9940>,
#  '只不過': <gensim.models.keyedvectors.Vocab at 0x10c5f90f0>,
#  '而已': <gensim.models.keyedvectors.Vocab at 0x10c5f9438>,
#  '現在': <gensim.models.keyedvectors.Vocab at 0x10c5f9518>,
#  '聯盟': <gensim.models.keyedvectors.Vocab at 0x10c5f9ac8>,
#  '幾個': <gensim.models.keyedvectors.Vocab at 0x10c5f9e10>,
#  '強隊': <gensim.models.keyedvectors.Vocab at 0x10c5f9908>,
#  '騎': <gensim.models.keyedvectors.Vocab at 0x10c5f98d0>,
#  'PG': <gensim.models.keyedvectors.Vocab at 0x10c5f9cc0>,
#  '話': <gensim.models.keyedvectors.Vocab at 0x10c5f9630>,
#  '空降': <gensim.models.keyedvectors.Vocab at 0x10c5f9a20>,
#  '哪': <gensim.models.keyedvectors.Vocab at 0x10c5f9748>,
#  '隻': <gensim.models.keyedvectors.Vocab at 0x10c5f94a8>,
#  '信': <gensim.models.keyedvectors.Vocab at 0x10c5f9710>,
#  '明年': <gensim.models.keyedvectors.Vocab at 0x10c5f9fd0>,
#  '阿': <gensim.models.keyedvectors.Vocab at 0x10c5f9e48>,
#  '便宜': <gensim.models.keyedvectors.Vocab at 0x10c5f99e8>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x10c5f9d30>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x10bfb9048>,
#  '30M': <gensim.models.keyedvectors.Vocab at 0x10bfb9080>,
#  '簽不': <gensim.models.keyedvectors.Vocab at 0x10bfb97f0>,
#  '下來': <gensim.models.keyedvectors.Vocab at 0x10bfb96a0>,
#  '機會': <gensim.models.keyedvectors.Vocab at 0x10bfb9828>,
#  '兩個': <gensim.models.keyedvectors.Vocab at 0x10bfb9668>,
#  '組了': <gensim.models.keyedvectors.Vocab at 0x10bfb90b8>,
#  '雙塔': <gensim.models.keyedvectors.Vocab at 0x10bfb9748>,
#  '假日': <gensim.models.keyedvectors.Vocab at 0x10bfb9400>,
#  '更好': <gensim.models.keyedvectors.Vocab at 0x10bfb9908>,
#  '傳言': <gensim.models.keyedvectors.Vocab at 0x10bfb98d0>,
#  '拉': <gensim.models.keyedvectors.Vocab at 0x10bfb9a90>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x10bfb9240>,
#  '我們': <gensim.models.keyedvectors.Vocab at 0x10bfb9fd0>,
#  '薪水': <gensim.models.keyedvectors.Vocab at 0x10bfb9ef0>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x10bfb9860>,
#  '扯': <gensim.models.keyedvectors.Vocab at 0x10bfb9b00>,
#  '無言': <gensim.models.keyedvectors.Vocab at 0x10bfb9b38>,
#  '紀錄': <gensim.models.keyedvectors.Vocab at 0x10bfb9c50>,
#  '以為': <gensim.models.keyedvectors.Vocab at 0x10bfb9f98>,
#  'FBI': <gensim.models.keyedvectors.Vocab at 0x10bfb9e48>,
#  '喔': <gensim.models.keyedvectors.Vocab at 0x10bfb9cf8>,
#  '爛': <gensim.models.keyedvectors.Vocab at 0x10bfb9518>,
#  '鬼': <gensim.models.keyedvectors.Vocab at 0x10bfb9a58>,
#  '這有': <gensim.models.keyedvectors.Vocab at 0x10bfb9be0>,
#  '啥': <gensim.models.keyedvectors.Vocab at 0x10bfb9d68>,
#  '季後賽': <gensim.models.keyedvectors.Vocab at 0x10bfb99b0>,
#  '等級': <gensim.models.keyedvectors.Vocab at 0x10bfb9c88>,
#  '血戰': <gensim.models.keyedvectors.Vocab at 0x10bfb9cc0>,
#  '形容': <gensim.models.keyedvectors.Vocab at 0x10bfb9978>,
#  '有沒有': <gensim.models.keyedvectors.Vocab at 0x10bfb9390>,
#  '查': <gensim.models.keyedvectors.Vocab at 0x10bfb9da0>,
#  '一下': <gensim.models.keyedvectors.Vocab at 0x10bfb9ba8>,
#  '理查': <gensim.models.keyedvectors.Vocab at 0x10bfb9dd8>,
#  '4000': <gensim.models.keyedvectors.Vocab at 0x10bfb9710>,
#  '萬': <gensim.models.keyedvectors.Vocab at 0x10bfb9898>,
#  '極限': <gensim.models.keyedvectors.Vocab at 0x10bfb9a20>,
#  '晚': <gensim.models.keyedvectors.Vocab at 0x10bfb94e0>,
#  '簽也': <gensim.models.keyedvectors.Vocab at 0x10bfb99e8>,
#  '一樣': <gensim.models.keyedvectors.Vocab at 0x10bfb9780>,
#  '很大': <gensim.models.keyedvectors.Vocab at 0x10bfb9198>,
#  '跳出': <gensim.models.keyedvectors.Vocab at 0x10bfb97b8>,
#  '小綠': <gensim.models.keyedvectors.Vocab at 0x10bfb94a8>,
#  '跳': <gensim.models.keyedvectors.Vocab at 0x10bfb96d8>,
#  '1000': <gensim.models.keyedvectors.Vocab at 0x10bfb95c0>,
#  '不信': <gensim.models.keyedvectors.Vocab at 0x10bfb9470>,
#  '剌': <gensim.models.keyedvectors.Vocab at 0x10bfb9358>,
#  '這樣': <gensim.models.keyedvectors.Vocab at 0x10bfb9550>,
#  '書豪': <gensim.models.keyedvectors.Vocab at 0x10bfb9b70>,
#  '有望': <gensim.models.keyedvectors.Vocab at 0x10bfb9630>,
#  '正常': <gensim.models.keyedvectors.Vocab at 0x10bfb9588>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x10bfb9160>,
#  '牆哥': <gensim.models.keyedvectors.Vocab at 0x10bfb92b0>,
#  '爭冠': <gensim.models.keyedvectors.Vocab at 0x10bfb90f0>,
#  '絕不能': <gensim.models.keyedvectors.Vocab at 0x10bfb9c18>,
#  '輸': <gensim.models.keyedvectors.Vocab at 0x10bfb9320>,
#  'KI': <gensim.models.keyedvectors.Vocab at 0x10bfb9208>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x10bfb9438>,
#  '陣容': <gensim.models.keyedvectors.Vocab at 0x10bfb9ac8>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x10bfb9e80>,
#  '喊': <gensim.models.keyedvectors.Vocab at 0x10bfb93c8>,
#  '簽了': <gensim.models.keyedvectors.Vocab at 0x10bfb91d0>,
#  '最後': <gensim.models.keyedvectors.Vocab at 0x10bfb9e10>,
#  '回': <gensim.models.keyedvectors.Vocab at 0x10bfb9940>,
#  '沒錢': <gensim.models.keyedvectors.Vocab at 0x10bfb9d30>,
#  '追': <gensim.models.keyedvectors.Vocab at 0x10bfb95f8>,
#  '清': <gensim.models.keyedvectors.Vocab at 0x109654588>,
#  '情況': <gensim.models.keyedvectors.Vocab at 0x109654630>,
#  '吃屎': <gensim.models.keyedvectors.Vocab at 0x107111e10>,
#  '個人': <gensim.models.keyedvectors.Vocab at 0x107111e80>,
#  '覺得': <gensim.models.keyedvectors.Vocab at 0x10c4cd5f8>,
#  '進': <gensim.models.keyedvectors.Vocab at 0x10c4cd240>,
#  'FA': <gensim.models.keyedvectors.Vocab at 0x10c4cd780>,
#  '市場': <gensim.models.keyedvectors.Vocab at 0x10c4cdb00>,
#  '看看': <gensim.models.keyedvectors.Vocab at 0x10c4cdbe0>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x10c4cd2e8>,
#  '決定': <gensim.models.keyedvectors.Vocab at 0x10c4cd4e0>,
#  '版主': <gensim.models.keyedvectors.Vocab at 0x10c4cd588>,
#  '東西': <gensim.models.keyedvectors.Vocab at 0x10c4cde10>,
#  '限制': <gensim.models.keyedvectors.Vocab at 0x10c4cd550>,
#  '雖然': <gensim.models.keyedvectors.Vocab at 0x10c4cd860>,
#  '廢文': <gensim.models.keyedvectors.Vocab at 0x10c4cd4a8>,
#  '請': <gensim.models.keyedvectors.Vocab at 0x10c4cd358>,
#  '與': <gensim.models.keyedvectors.Vocab at 0x10c4cd320>,
#  '喇叭': <gensim.models.keyedvectors.Vocab at 0x10c4cd630>,
#  'pk': <gensim.models.keyedvectors.Vocab at 0x10c4cd208>,
#  '怎麼': <gensim.models.keyedvectors.Vocab at 0x10c4cd438>,
#  '刺': <gensim.models.keyedvectors.Vocab at 0x10c4cd128>,
#  '迷要': <gensim.models.keyedvectors.Vocab at 0x10c4cd390>,
#  '直播': <gensim.models.keyedvectors.Vocab at 0x10c4cdeb8>,
#  '拿到': <gensim.models.keyedvectors.Vocab at 0x10c4cd3c8>,
#  '太爽了': <gensim.models.keyedvectors.Vocab at 0x10c4cd2b0>,
#  '87': <gensim.models.keyedvectors.Vocab at 0x10c4cd470>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x10c4cd080>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x10c4cd0b8>,
#  '寧願': <gensim.models.keyedvectors.Vocab at 0x10c4cd7b8>,
#  '拼個': <gensim.models.keyedvectors.Vocab at 0x10c4cd940>,
#  '你死我活': <gensim.models.keyedvectors.Vocab at 0x10c4cd6a0>,
#  '願意': <gensim.models.keyedvectors.Vocab at 0x10c4cd1d0>,
#  '挑': <gensim.models.keyedvectors.Vocab at 0x10c4cd160>,
#  '戰': <gensim.models.keyedvectors.Vocab at 0x10c4cde80>,
#  'LBJ': <gensim.models.keyedvectors.Vocab at 0x10c4cdb38>,
#  '姆斯': <gensim.models.keyedvectors.Vocab at 0x10c4cdac8>,
#  '喬丹': <gensim.models.keyedvectors.Vocab at 0x10c4cdba8>,
#  '輕鬆': <gensim.models.keyedvectors.Vocab at 0x10c4cda90>,
#  '屌': <gensim.models.keyedvectors.Vocab at 0x10c4cdc18>,
#  '虐': <gensim.models.keyedvectors.Vocab at 0x10c4cd9b0>,
#  '敢': <gensim.models.keyedvectors.Vocab at 0x10c4cda20>,
#  '送走': <gensim.models.keyedvectors.Vocab at 0x10c4cd7f0>,
#  '傻子': <gensim.models.keyedvectors.Vocab at 0x10c4cd278>,
#  '搞': <gensim.models.keyedvectors.Vocab at 0x10c4cda58>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x10c4cd978>,
#  '三小': <gensim.models.keyedvectors.Vocab at 0x10c4cd8d0>,
#  '兩年': <gensim.models.keyedvectors.Vocab at 0x10c4cd9e8>,
#  '合約': <gensim.models.keyedvectors.Vocab at 0x10c4cd710>,
#  '甚麼': <gensim.models.keyedvectors.Vocab at 0x10c4cd748>,
#  '別': <gensim.models.keyedvectors.Vocab at 0x10c4cd828>,
#  '鬼扯': <gensim.models.keyedvectors.Vocab at 0x10c4cd908>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x10c4cdef0>,
#  '再說': <gensim.models.keyedvectors.Vocab at 0x10c4cd668>,
#  '說不定': <gensim.models.keyedvectors.Vocab at 0x10c4cd048>,
#  '主動': <gensim.models.keyedvectors.Vocab at 0x10c4cde48>,
#  '降價': <gensim.models.keyedvectors.Vocab at 0x10c4cdf28>,
#  '繼承': <gensim.models.keyedvectors.Vocab at 0x10c4cdc88>,
#  '傳統': <gensim.models.keyedvectors.Vocab at 0x10c4cd518>,
#  '只好': <gensim.models.keyedvectors.Vocab at 0x10c4cdda0>,
#  '收': <gensim.models.keyedvectors.Vocab at 0x10c4cddd8>,
#  '小虧': <gensim.models.keyedvectors.Vocab at 0x10c4cdcc0>,
#  '躲姆斯': <gensim.models.keyedvectors.Vocab at 0x10c4cdd68>,
#  '年薪': <gensim.models.keyedvectors.Vocab at 0x10c4cdc50>,
#  '組': <gensim.models.keyedvectors.Vocab at 0x10c4cdd30>,
#  '一隻': <gensim.models.keyedvectors.Vocab at 0x10c4cdf98>,
#  '籃': <gensim.models.keyedvectors.Vocab at 0x10c4cdcf8>,
#  '網隊': <gensim.models.keyedvectors.Vocab at 0x10c4cdb70>,
#  '送': <gensim.models.keyedvectors.Vocab at 0x10c4cdf60>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x10c4cd898>,
#  '台': <gensim.models.keyedvectors.Vocab at 0x10c4d7748>,
#  '唬爛': <gensim.models.keyedvectors.Vocab at 0x10c4d7f98>,
#  '過頭': <gensim.models.keyedvectors.Vocab at 0x10c4d7eb8>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x10c4d7128>,
#  '不贏': <gensim.models.keyedvectors.Vocab at 0x10c4d7a20>,
#  '轉': <gensim.models.keyedvectors.Vocab at 0x10c4d73c8>,
#  'parker': <gensim.models.keyedvectors.Vocab at 0x10c4d7d30>,
#  '時': <gensim.models.keyedvectors.Vocab at 0x10c4d7ef0>,
#  '除了': <gensim.models.keyedvectors.Vocab at 0x10c4d7c88>,
#  '低能': <gensim.models.keyedvectors.Vocab at 0x10c4d7b70>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x10c4d7cc0>,
#  '連': <gensim.models.keyedvectors.Vocab at 0x10c4d7c50>,
#  '內容': <gensim.models.keyedvectors.Vocab at 0x10c4d7ac8>,
#  '看球': <gensim.models.keyedvectors.Vocab at 0x10c4d7b38>,
#  '寫': <gensim.models.keyedvectors.Vocab at 0x10c4d7c18>,
#  '反正': <gensim.models.keyedvectors.Vocab at 0x10c4d7a90>,
#  '讓': <gensim.models.keyedvectors.Vocab at 0x10c4d7da0>,
#  '平靜': <gensim.models.keyedvectors.Vocab at 0x10c4d7a58>,
#  '迷先': <gensim.models.keyedvectors.Vocab at 0x10c4d7860>,
#  '嘴': <gensim.models.keyedvectors.Vocab at 0x10c4d7908>,
#  '不管': <gensim.models.keyedvectors.Vocab at 0x10c4d7940>,
#  '一堆': <gensim.models.keyedvectors.Vocab at 0x10c4d76d8>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x10c4d7b00>,
#  '文章': <gensim.models.keyedvectors.Vocab at 0x10c4d78d0>,
#  '鄉民': <gensim.models.keyedvectors.Vocab at 0x10c4d7978>,
#  '智障': <gensim.models.keyedvectors.Vocab at 0x10c4d7588>,
#  '得到': <gensim.models.keyedvectors.Vocab at 0x10c4d77b8>,
#  'agg': <gensim.models.keyedvectors.Vocab at 0x10c4d7668>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x10c4d7828>,
#  'tp': <gensim.models.keyedvectors.Vocab at 0x10c4d7518>,
#  '意外': <gensim.models.keyedvectors.Vocab at 0x10c4d7780>,
#  '40m': <gensim.models.keyedvectors.Vocab at 0x10c4d7710>,
#  '左右': <gensim.models.keyedvectors.Vocab at 0x10c4d76a0>,
#  '哪裡': <gensim.models.keyedvectors.Vocab at 0x10c4d74a8>,
#  '本來': <gensim.models.keyedvectors.Vocab at 0x10c4d7438>,
#  '招': <gensim.models.keyedvectors.Vocab at 0x10c4d7320>,
#  '結果': <gensim.models.keyedvectors.Vocab at 0x10c4d72b0>,
#  '開市': <gensim.models.keyedvectors.Vocab at 0x10c4d7630>,
#  '第一天': <gensim.models.keyedvectors.Vocab at 0x10c4d7390>,
#  '門': <gensim.models.keyedvectors.Vocab at 0x10c4d74e0>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x10c4d72e8>,
#  '哦': <gensim.models.keyedvectors.Vocab at 0x10c4d7080>,
#  '江沃': <gensim.models.keyedvectors.Vocab at 0x10c4d7358>,
#  '不見得': <gensim.models.keyedvectors.Vocab at 0x10c4d75c0>,
#  '討': <gensim.models.keyedvectors.Vocab at 0x10c4d70b8>,
#  '全明星': <gensim.models.keyedvectors.Vocab at 0x10c4d7278>,
#  '進不去': <gensim.models.keyedvectors.Vocab at 0x10c4d7400>,
#  '幹': <gensim.models.keyedvectors.Vocab at 0x10c4d71d0>,
#  '這麼': <gensim.models.keyedvectors.Vocab at 0x10c4d75f8>,
#  '球星': <gensim.models.keyedvectors.Vocab at 0x10c4d7048>,
#  '簡直': <gensim.models.keyedvectors.Vocab at 0x10c4d7240>,
#  '原文': <gensim.models.keyedvectors.Vocab at 0x10c4d7160>,
#  '視為': <gensim.models.keyedvectors.Vocab at 0x10c4d7f28>,
#  '窮': <gensim.models.keyedvectors.Vocab at 0x10c4d7198>,
#  'QQ': <gensim.models.keyedvectors.Vocab at 0x10c4d79e8>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x10c4d7dd8>,
#  '不想': <gensim.models.keyedvectors.Vocab at 0x10c4d7e80>,
#  '誰知': <gensim.models.keyedvectors.Vocab at 0x10c4d7208>,
#  '道': <gensim.models.keyedvectors.Vocab at 0x10c4d7f60>,
#  '怎樣': <gensim.models.keyedvectors.Vocab at 0x10c4d7cf8>,
#  '權利': <gensim.models.keyedvectors.Vocab at 0x10c4d7fd0>,
#  '選擇': <gensim.models.keyedvectors.Vocab at 0x10c4d7d68>,
#  '亂說': <gensim.models.keyedvectors.Vocab at 0x10c4d7ba8>,
#  '白癡': <gensim.models.keyedvectors.Vocab at 0x10c4d7e10>,
#  '依據': <gensim.models.keyedvectors.Vocab at 0x10c4d7be0>,
#  '第': <gensim.models.keyedvectors.Vocab at 0x106cb84e0>,
#  '期': <gensim.models.keyedvectors.Vocab at 0x10c4ad048>,
#  '即將': <gensim.models.keyedvectors.Vocab at 0x10c4ad080>,
#  '發': <gensim.models.keyedvectors.Vocab at 0x10c4ad0b8>,
#  '亞軍': <gensim.models.keyedvectors.Vocab at 0x10c4ad0f0>,
#  '傳說': <gensim.models.keyedvectors.Vocab at 0x10c4ad128>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x10c4ad160>,
#  '想像': <gensim.models.keyedvectors.Vocab at 0x10c4ad198>,
#  '昨天': <gensim.models.keyedvectors.Vocab at 0x10c4ad1d0>,
#  '十': <gensim.models.keyedvectors.Vocab at 0x10c4ad208>,
#  '轉貼': <gensim.models.keyedvectors.Vocab at 0x10c4ad240>,
#  '中國': <gensim.models.keyedvectors.Vocab at 0x10c4ad278>,
#  '運動': <gensim.models.keyedvectors.Vocab at 0x10c4ad2b0>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x10c4ad2e8>,
#  '站': <gensim.models.keyedvectors.Vocab at 0x10c4ad320>,
#  '消息': <gensim.models.keyedvectors.Vocab at 0x10c4ad358>,
#  '來自': <gensim.models.keyedvectors.Vocab at 0x10c4ad390>,
#  'Tim': <gensim.models.keyedvectors.Vocab at 0x10c4ad400>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x10c4ad438>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x10c4ad470>,
#  '這則': <gensim.models.keyedvectors.Vocab at 0x10c4ad4a8>,
#  '蛤': <gensim.models.keyedvectors.Vocab at 0x10c4ad4e0>,
#  '欠': <gensim.models.keyedvectors.Vocab at 0x10c4ad518>,
#  '廢': <gensim.models.keyedvectors.Vocab at 0x10c4ad550>,
#  '認真': <gensim.models.keyedvectors.Vocab at 0x10c4ad588>,
#  '問': <gensim.models.keyedvectors.Vocab at 0x10c4ad5c0>,
#  '明明': <gensim.models.keyedvectors.Vocab at 0x10c4ad5f8>,
#  '壟斷': <gensim.models.keyedvectors.Vocab at 0x10c4ad630>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x10c4ad668>,
#  '要成': <gensim.models.keyedvectors.Vocab at 0x10c4ad6a0>,
#  '四皇': <gensim.models.keyedvectors.Vocab at 0x10c4ad6d8>,
#  '天下': <gensim.models.keyedvectors.Vocab at 0x10c4ad710>,
#  '勇': <gensim.models.keyedvectors.Vocab at 0x10c4ad748>,
#  '箭': <gensim.models.keyedvectors.Vocab at 0x10c4ad780>,
#  '雷': <gensim.models.keyedvectors.Vocab at 0x10c4ad7b8>,
#  '哪來': <gensim.models.keyedvectors.Vocab at 0x10c4ad7f0>,
#  '簽他': <gensim.models.keyedvectors.Vocab at 0x10c4ad828>,
#  '付': <gensim.models.keyedvectors.Vocab at 0x10c4ad860>,
#  '豪華': <gensim.models.keyedvectors.Vocab at 0x10c4ad898>,
#  '稅': <gensim.models.keyedvectors.Vocab at 0x10c4ad8d0>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x10c4ad908>,
#  '賺': <gensim.models.keyedvectors.Vocab at 0x10c4ad940>,
#  '萬元': <gensim.models.keyedvectors.Vocab at 0x10c4ad978>,
#  '應有': <gensim.models.keyedvectors.Vocab at 0x10c4ad9b0>,
#  '付錢': <gensim.models.keyedvectors.Vocab at 0x10c4ad9e8>,
#  '一向': <gensim.models.keyedvectors.Vocab at 0x10c4ada20>,
#  '不太': <gensim.models.keyedvectors.Vocab at 0x10c4ada58>,
#  '大方': <gensim.models.keyedvectors.Vocab at 0x10c4ada90>,
#  '賺錢': <gensim.models.keyedvectors.Vocab at 0x10c4adac8>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x10c4adb00>,
#  '戰績': <gensim.models.keyedvectors.Vocab at 0x10c4adb38>,
#  '難': <gensim.models.keyedvectors.Vocab at 0x10c4adb70>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x10c4adbe0>,
#  'youtu': <gensim.models.keyedvectors.Vocab at 0x10c4adc50>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x10c4adcc0>,
#  '支持': <gensim.models.keyedvectors.Vocab at 0x10c4adcf8>,
#  '畫面': <gensim.models.keyedvectors.Vocab at 0x10c4add30>,
#  '美': <gensim.models.keyedvectors.Vocab at 0x10c4add68>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x10c4adda0>,
#  '頒獎': <gensim.models.keyedvectors.Vocab at 0x10c4addd8>,
#  '討厭': <gensim.models.keyedvectors.Vocab at 0x10c4ade10>,
#  '大法': <gensim.models.keyedvectors.Vocab at 0x10c4ade48>,
#  '大哥': <gensim.models.keyedvectors.Vocab at 0x10c4ade80>,
#  '黑暗': <gensim.models.keyedvectors.Vocab at 0x10c4adeb8>,
#  '兵法': <gensim.models.keyedvectors.Vocab at 0x10c4adef0>,
#  '丟': <gensim.models.keyedvectors.Vocab at 0x10c4adf28>,
#  '期待': <gensim.models.keyedvectors.Vocab at 0x10c4adf60>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x10c4adf98>,
#  '講': <gensim.models.keyedvectors.Vocab at 0x10c4adfd0>,
#  '還太早': <gensim.models.keyedvectors.Vocab at 0x10c492048>,
#  '恐': <gensim.models.keyedvectors.Vocab at 0x10c492080>,
#  '刺迷': <gensim.models.keyedvectors.Vocab at 0x10c4920b8>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x10c4920f0>,
#  '你講': <gensim.models.keyedvectors.Vocab at 0x10c492128>,
#  'pg': <gensim.models.keyedvectors.Vocab at 0x10c492198>,
#  '不僅': <gensim.models.keyedvectors.Vocab at 0x10c4921d0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x10c492208>,
#  '號位': <gensim.models.keyedvectors.Vocab at 0x10c492240>,
#  '禁區': <gensim.models.keyedvectors.Vocab at 0x10c492278>,
#  '剩': <gensim.models.keyedvectors.Vocab at 0x10c4922b0>,
#  'Gasol': <gensim.models.keyedvectors.Vocab at 0x10c492320>,
#  '菜': <gensim.models.keyedvectors.Vocab at 0x10c492358>,
#  '逼': <gensim.models.keyedvectors.Vocab at 0x10c492390>,
#  '巴': <gensim.models.keyedvectors.Vocab at 0x10c4923c8>,
#  'bertans': <gensim.models.keyedvectors.Vocab at 0x10c492438>,
#  '搞笑': <gensim.models.keyedvectors.Vocab at 0x10c492470>,
#  '逆': <gensim.models.keyedvectors.Vocab at 0x10c4924a8>,
#  '$': <gensim.models.keyedvectors.Vocab at 0x10c4924e0>,
#  '夢': <gensim.models.keyedvectors.Vocab at 0x10c492518>,
#  '最美': <gensim.models.keyedvectors.Vocab at 0x10c492550>,
#  '靠': <gensim.models.keyedvectors.Vocab at 0x10c492588>,
#  '薪資': <gensim.models.keyedvectors.Vocab at 0x10c4925c0>,
#  '～': <gensim.models.keyedvectors.Vocab at 0x10c4925f8>,
#  'Curry': <gensim.models.keyedvectors.Vocab at 0x10c492668>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x10c4926a0>,
#  '竟然': <gensim.models.keyedvectors.Vocab at 0x10c4926d8>,
#  'G': <gensim.models.keyedvectors.Vocab at 0x10c492710>,
#  '想當年': <gensim.models.keyedvectors.Vocab at 0x10c492748>,
#  '如今': <gensim.models.keyedvectors.Vocab at 0x10c492780>,
#  '北七': <gensim.models.keyedvectors.Vocab at 0x10c4927b8>,
#  '馬': <gensim.models.keyedvectors.Vocab at 0x10c4927f0>,
#  '問過': <gensim.models.keyedvectors.Vocab at 0x10c492828>,
#  '某迷': <gensim.models.keyedvectors.Vocab at 0x10c492860>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x10c492898>,
#  '會來': <gensim.models.keyedvectors.Vocab at 0x10c4928d0>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x10c492908>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x10c492940>,
#  '在意': <gensim.models.keyedvectors.Vocab at 0x10c492978>,
#  '看來': <gensim.models.keyedvectors.Vocab at 0x10c4929b0>,
#  '距離': <gensim.models.keyedvectors.Vocab at 0x10c4929e8>,
#  '豪哥': <gensim.models.keyedvectors.Vocab at 0x10c492a20>,
#  '賽先發': <gensim.models.keyedvectors.Vocab at 0x10c492a58>,
#  '日子': <gensim.models.keyedvectors.Vocab at 0x10c492a90>,
#  '不遠': <gensim.models.keyedvectors.Vocab at 0x10c492ac8>,
#  '狂': <gensim.models.keyedvectors.Vocab at 0x10c492b00>,
#  '其實': <gensim.models.keyedvectors.Vocab at 0x10c492b38>,
#  '升級': <gensim.models.keyedvectors.Vocab at 0x10c492b70>,
#  '別去': <gensim.models.keyedvectors.Vocab at 0x10c492ba8>,
#  '打敗': <gensim.models.keyedvectors.Vocab at 0x10c492be0>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x10c492c18>,
#  '東冠': <gensim.models.keyedvectors.Vocab at 0x10c492c50>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x10c492c88>,
#  '4y': <gensim.models.keyedvectors.Vocab at 0x10c492cf8>,
#  '萬美金': <gensim.models.keyedvectors.Vocab at 0x10c492d30>,
#  '還不': <gensim.models.keyedvectors.Vocab at 0x10c492d68>,
#  '滿足': <gensim.models.keyedvectors.Vocab at 0x10c492da0>,
#  '這張': <gensim.models.keyedvectors.Vocab at 0x10c492dd8>,
#  '破壞': <gensim.models.keyedvectors.Vocab at 0x10c492e10>,
#  '行情': <gensim.models.keyedvectors.Vocab at 0x10c492e48>,
#  '抱': <gensim.models.keyedvectors.Vocab at 0x10c492e80>,
#  '腿': <gensim.models.keyedvectors.Vocab at 0x10c492eb8>,
#  '沒什麼': <gensim.models.keyedvectors.Vocab at 0x10c492ef0>,
#  'ㄤ': <gensim.models.keyedvectors.Vocab at 0x10c492f28>,
#  'Mills': <gensim.models.keyedvectors.Vocab at 0x10c492f98>,
#  '還來': <gensim.models.keyedvectors.Vocab at 0x10c492fd0>,
#  '欺負': <gensim.models.keyedvectors.Vocab at 0x10c496048>,
#  '嗚嗚': <gensim.models.keyedvectors.Vocab at 0x10c496080>,
#  '閒聊': <gensim.models.keyedvectors.Vocab at 0x10c4960b8>,
#  '關於': <gensim.models.keyedvectors.Vocab at 0x10c4960f0>,
#  'KL': <gensim.models.keyedvectors.Vocab at 0x10c496160>,
#  '剛剛': <gensim.models.keyedvectors.Vocab at 0x10c496198>,
#  'FB': <gensim.models.keyedvectors.Vocab at 0x10c496208>,
#  '模範生': <gensim.models.keyedvectors.Vocab at 0x10c496240>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x10c496278>,
#  '場邊': <gensim.models.keyedvectors.Vocab at 0x10c4962b0>,
#  '透露': <gensim.models.keyedvectors.Vocab at 0x10c4962e8>,
#  'Kawhi': <gensim.models.keyedvectors.Vocab at 0x10c496358>,
#  'Leonard': <gensim.models.keyedvectors.Vocab at 0x10c4963c8>,
#  '進入': <gensim.models.keyedvectors.Vocab at 0x10c496400>,
#  '球場': <gensim.models.keyedvectors.Vocab at 0x10c496438>,
#  '練': <gensim.models.keyedvectors.Vocab at 0x10c496470>,
#  '投': <gensim.models.keyedvectors.Vocab at 0x10c4964a8>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x10c4964e0>,
#  '支撐': <gensim.models.keyedvectors.Vocab at 0x10c496518>,
#  '任何': <gensim.models.keyedvectors.Vocab at 0x10c496550>,
#  '現象': <gensim.models.keyedvectors.Vocab at 0x10c496588>,
#  '種種': <gensim.models.keyedvectors.Vocab at 0x10c4965c0>,
#  '跡象': <gensim.models.keyedvectors.Vocab at 0x10c4965f8>,
#  '顯示': <gensim.models.keyedvectors.Vocab at 0x10c496630>,
#  '今晚': <gensim.models.keyedvectors.Vocab at 0x10c496668>,
#  '健康': <gensim.models.keyedvectors.Vocab at 0x10c4966a0>,
#  '姿態': <gensim.models.keyedvectors.Vocab at 0x10c4966d8>,
#  '登場': <gensim.models.keyedvectors.Vocab at 0x10c496710>,
#  '連結': <gensim.models.keyedvectors.Vocab at 0x10c496748>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x10c4967b8>,
#  'goo': <gensim.models.keyedvectors.Vocab at 0x10c496828>,
#  'gl': <gensim.models.keyedvectors.Vocab at 0x10c496898>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x10c4968d0>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x10c496940>,
#  '分鐘': <gensim.models.keyedvectors.Vocab at 0x10c496978>,
#  '以內': <gensim.models.keyedvectors.Vocab at 0x10c4969b0>,
#  '打卡': <gensim.models.keyedvectors.Vocab at 0x10c4969e8>,
#  '下班': <gensim.models.keyedvectors.Vocab at 0x10c496a20>,
#  '05': <gensim.models.keyedvectors.Vocab at 0x10c496a90>,
#  '加油': <gensim.models.keyedvectors.Vocab at 0x10c496ac8>,
#  '借轉': <gensim.models.keyedvectors.Vocab at 0x10c496b00>,
#  '總版': <gensim.models.keyedvectors.Vocab at 0x10c496b38>,
#  'pagenotfound': <gensim.models.keyedvectors.Vocab at 0x10c496b70>,
#  '還以': <gensim.models.keyedvectors.Vocab at 0x10c496ba8>,
#  'Kevin': <gensim.models.keyedvectors.Vocab at 0x10c496c18>,
#  'Love': <gensim.models.keyedvectors.Vocab at 0x10c496c88>,
#  '關門': <gensim.models.keyedvectors.Vocab at 0x10c496cc0>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x10c496cf8>,
#  'Kyle': <gensim.models.keyedvectors.Vocab at 0x10c496d68>,
#  'Lowry': <gensim.models.keyedvectors.Vocab at 0x10c496dd8>,
#  '小貝': <gensim.models.keyedvectors.Vocab at 0x10c496e10>,
#  '可憐': <gensim.models.keyedvectors.Vocab at 0x10c496e48>,
#  '受傷': <gensim.models.keyedvectors.Vocab at 0x10c496e80>,
#  '估計': <gensim.models.keyedvectors.Vocab at 0x10c496eb8>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x10c496f28>,
#  '千萬': <gensim.models.keyedvectors.Vocab at 0x10c496f60>,
#  '敗': <gensim.models.keyedvectors.Vocab at 0x10c496f98>,
#  '抓': <gensim.models.keyedvectors.Vocab at 0x10c496fd0>,
#  '愛神': <gensim.models.keyedvectors.Vocab at 0x10c4a8048>,
#  '辦法': <gensim.models.keyedvectors.Vocab at 0x10c4a8080>,
#  '傷勢': <gensim.models.keyedvectors.Vocab at 0x10c4a80b8>,
#  '卻': <gensim.models.keyedvectors.Vocab at 0x10c4a80f0>,
#  '教練': <gensim.models.keyedvectors.Vocab at 0x10c4a8128>,
#  '頭痛': <gensim.models.keyedvectors.Vocab at 0x10c4a8160>,
#  '乾': <gensim.models.keyedvectors.Vocab at 0x10c4a8198>,
#  '騙人': <gensim.models.keyedvectors.Vocab at 0x10c4a81d0>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x10c4a8240>,
#  '第六': <gensim.models.keyedvectors.Vocab at 0x10c4a8278>,
#  '扭傷': <gensim.models.keyedvectors.Vocab at 0x10c4a82b0>,
#  '那麼': <gensim.models.keyedvectors.Vocab at 0x10c4a82e8>,
#  '上場': <gensim.models.keyedvectors.Vocab at 0x10c4a8320>,
#  '果然': <gensim.models.keyedvectors.Vocab at 0x10c4a8358>,
#  '機器人': <gensim.models.keyedvectors.Vocab at 0x10c4a8390>,
#  '機油': <gensim.models.keyedvectors.Vocab at 0x10c4a83c8>,
#  '好惹': <gensim.models.keyedvectors.Vocab at 0x10c4a8400>,
#  '剛好': <gensim.models.keyedvectors.Vocab at 0x10c4a8438>,
#  '腳踝': <gensim.models.keyedvectors.Vocab at 0x10c4a8470>,
#  '管': <gensim.models.keyedvectors.Vocab at 0x10c4a84a8>,
#  '維修': <gensim.models.keyedvectors.Vocab at 0x10c4a84e0>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x10c4a8518>,
#  'GoSpursGo': <gensim.models.keyedvectors.Vocab at 0x10c4a8550>,
#  '馬刺進': <gensim.models.keyedvectors.Vocab at 0x10c4a8588>,
#  '西冠': <gensim.models.keyedvectors.Vocab at 0x10c4a85c0>,
#  'Popo': <gensim.models.keyedvectors.Vocab at 0x10c4a8630>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x10c4a8668>,
#  '採訪': <gensim.models.keyedvectors.Vocab at 0x10c4a86a0>,
#  'Game': <gensim.models.keyedvectors.Vocab at 0x10c4a8710>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x10c4a8780>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x10c4a87b8>,
#  '謙卑': <gensim.models.keyedvectors.Vocab at 0x10c4a87f0>,
#  '週一': <gensim.models.keyedvectors.Vocab at 0x10c4a8828>,
#  '打球': <gensim.models.keyedvectors.Vocab at 0x10c4a8860>,
#  '小扭': <gensim.models.keyedvectors.Vocab at 0x10c4a8898>,
#  '還在': <gensim.models.keyedvectors.Vocab at 0x10c4a88d0>,
#  '痠': <gensim.models.keyedvectors.Vocab at 0x10c4a8908>,
#  '吹': <gensim.models.keyedvectors.Vocab at 0x10c4a8940>,
#  '沒事': <gensim.models.keyedvectors.Vocab at 0x10c4a8978>,
#  '延長': <gensim.models.keyedvectors.Vocab at 0x10c4a89b0>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x10c4a89e8>,
#  '他傷': <gensim.models.keyedvectors.Vocab at 0x10c4a8a20>,
#  '不輕': <gensim.models.keyedvectors.Vocab at 0x10c4a8a58>,
#  '故意': <gensim.models.keyedvectors.Vocab at 0x10c4a8a90>,
#  '輸掉': <gensim.models.keyedvectors.Vocab at 0x10c4a8ac8>,
#  '兩場': <gensim.models.keyedvectors.Vocab at 0x10c4a8b00>,
#  '休息': <gensim.models.keyedvectors.Vocab at 0x10c4a8b38>,
#  '暑假': <gensim.models.keyedvectors.Vocab at 0x10c4a8b70>,
#  '惹': <gensim.models.keyedvectors.Vocab at 0x10c4a8ba8>,
#  '以前': <gensim.models.keyedvectors.Vocab at 0x10c4a8be0>,
#  '刺傷': <gensim.models.keyedvectors.Vocab at 0x10c4a8c18>,
#  '深': <gensim.models.keyedvectors.Vocab at 0x10c4a8c50>,
#  '錯版': <gensim.models.keyedvectors.Vocab at 0x10c4a8c88>,
#  'spurs': <gensim.models.keyedvectors.Vocab at 0x10c4a8cf8>,
#  'Per': <gensim.models.keyedvectors.Vocab at 0x10c4a8d68>,
#  'Coach': <gensim.models.keyedvectors.Vocab at 0x10c4a8dd8>,
#  'Pop': <gensim.models.keyedvectors.Vocab at 0x10c4a8e48>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x10c4a8eb8>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x10c4a8f28>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x10c4a8f98>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x10c4c9048>,
#  '列入': <gensim.models.keyedvectors.Vocab at 0x10c4c9080>,
#  '黑名單': <gensim.models.keyedvectors.Vocab at 0x10c4c90b8>,
#  '弱': <gensim.models.keyedvectors.Vocab at 0x10c4c90f0>,
#  '耶': <gensim.models.keyedvectors.Vocab at 0x10c4c9128>,
#  '吹捧': <gensim.models.keyedvectors.Vocab at 0x10c4c9160>,
#  '生化': <gensim.models.keyedvectors.Vocab at 0x10c4c9198>,
#  '休': <gensim.models.keyedvectors.Vocab at 0x10c4c91d0>,
#  '崩潰': <gensim.models.keyedvectors.Vocab at 0x10c4c9208>,
#  'wwwwwwww': <gensim.models.keyedvectors.Vocab at 0x10c4c9240>,
#  '簽下': <gensim.models.keyedvectors.Vocab at 0x10c4c9278>,
#  'Joffrey': <gensim.models.keyedvectors.Vocab at 0x10c4c92e8>,
#  'Lauvergne': <gensim.models.keyedvectors.Vocab at 0x10c4c9320>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x10c4c9390>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x10c4c9400>,
#  'ShamsCharania': <gensim.models.keyedvectors.Vocab at 0x10c4c9438>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x10c4c94a8>,
#  'Free': <gensim.models.keyedvectors.Vocab at 0x10c4c9518>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x10c4c9588>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x10c4c95f8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x10c4c9668>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x10c4c96d8>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x10c4c9748>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x10c4c9780>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x10c4c97f0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x10c4c9860>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x10c4c98d0>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x10c4c9940>,
#  'Antonio': <gensim.models.keyedvectors.Vocab at 0x10c4c99b0>,
#  'Spurs': <gensim.models.keyedvectors.Vocab at 0x10c4c9a20>,
#  'league': <gensim.models.keyedvectors.Vocab at 0x10c4c9a90>,
#  'sources': <gensim.models.keyedvectors.Vocab at 0x10c4c9b00>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x10c4c9b70>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x10c4c9be0>,
#  'Vertical': <gensim.models.keyedvectors.Vocab at 0x10c4c9c18>,
#  '自由': <gensim.models.keyedvectors.Vocab at 0x10c4c9c50>,
#  'Wall62': <gensim.models.keyedvectors.Vocab at 0x10c4c9cc0>,
#  '49.213': <gensim.models.keyedvectors.Vocab at 0x10c4c9d30>,
#  '128.226': <gensim.models.keyedvectors.Vocab at 0x10c4c9da0>,
#  '適合': <gensim.models.keyedvectors.Vocab at 0x10c4c9dd8>,
#  '法國': <gensim.models.keyedvectors.Vocab at 0x10c4c9e10>,
#  'X': <gensim.models.keyedvectors.Vocab at 0x10c4c9e48>,
#  '補': <gensim.models.keyedvectors.Vocab at 0x10c4c9e80>,
#  '離開': <gensim.models.keyedvectors.Vocab at 0x10c4c9eb8>,
#  '後': <gensim.models.keyedvectors.Vocab at 0x10c4c9ef0>,
#  '還好': <gensim.models.keyedvectors.Vocab at 0x10c4c9f28>,
#  '懂': <gensim.models.keyedvectors.Vocab at 0x10c4c9f60>,
#  '何不': <gensim.models.keyedvectors.Vocab at 0x10c4c9f98>,
#  '留': <gensim.models.keyedvectors.Vocab at 0x10c4c9fd0>,
#  '裁': <gensim.models.keyedvectors.Vocab at 0x10c49f048>,
#  '撿': <gensim.models.keyedvectors.Vocab at 0x10c49f080>,
#  '牛': <gensim.models.keyedvectors.Vocab at 0x10c49f0b8>,
#  'Felicio': <gensim.models.keyedvectors.Vocab at 0x10c49f128>,
#  '芬蘭': <gensim.models.keyedvectors.Vocab at 0x10c49f160>,
#  '司機': <gensim.models.keyedvectors.Vocab at 0x10c49f198>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x10c49f1d0>,
#  '沒簽': <gensim.models.keyedvectors.Vocab at 0x10c49f208>,
#  'Mirotic': <gensim.models.keyedvectors.Vocab at 0x10c49f278>,
#  '人員': <gensim.models.keyedvectors.Vocab at 0x10c49f2b0>,
#  '何況': <gensim.models.keyedvectors.Vocab at 0x10c49f2e8>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x10c49f320>,
#  '目標': <gensim.models.keyedvectors.Vocab at 0x10c49f358>,
#  '狀元': <gensim.models.keyedvectors.Vocab at 0x10c49f390>,
#  '再簽': <gensim.models.keyedvectors.Vocab at 0x10c49f3c8>,
#  '球探': <gensim.models.keyedvectors.Vocab at 0x10c49f400>,
#  '做事': <gensim.models.keyedvectors.Vocab at 0x10c49f438>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x10c49f470>,
#  '感謝': <gensim.models.keyedvectors.Vocab at 0x10c49f4a8>,
#  '牛迷': <gensim.models.keyedvectors.Vocab at 0x10c49f4e0>,
#  '解答': <gensim.models.keyedvectors.Vocab at 0x10c49f518>,
#  'POPO': <gensim.models.keyedvectors.Vocab at 0x10c49f588>,
#  '管不動': <gensim.models.keyedvectors.Vocab at 0x10c49f5c0>,
#  '睡覺': <gensim.models.keyedvectors.Vocab at 0x10c49f5f8>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x10c49f630>,
#  '各種': <gensim.models.keyedvectors.Vocab at 0x10c49f668>,
#  'RJ': <gensim.models.keyedvectors.Vocab at 0x10c49f6d8>,
#  '笑': <gensim.models.keyedvectors.Vocab at 0x10c49f710>,
#  '死': <gensim.models.keyedvectors.Vocab at 0x10c49f748>,
#  '多人': <gensim.models.keyedvectors.Vocab at 0x10c49f780>,
#  '不行': <gensim.models.keyedvectors.Vocab at 0x10c49f7b8>,
#  '爛吧': <gensim.models.keyedvectors.Vocab at 0x10c49f7f0>,
#  '總覺': <gensim.models.keyedvectors.Vocab at 0x10c49f828>,
#  '心態': <gensim.models.keyedvectors.Vocab at 0x10c49f860>,
#  '擅長': <gensim.models.keyedvectors.Vocab at 0x10c49f898>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x10c49f8d0>,
#  '從來不': <gensim.models.keyedvectors.Vocab at 0x10c49f908>,
#  '視野': <gensim.models.keyedvectors.Vocab at 0x10c49f940>,
#  '太差': <gensim.models.keyedvectors.Vocab at 0x10c49f978>,
#  'Gay': <gensim.models.keyedvectors.Vocab at 0x10c49f9e8>,
#  'gay': <gensim.models.keyedvectors.Vocab at 0x10c49fa58>,
#  '賭': <gensim.models.keyedvectors.Vocab at 0x10c49fa90>,
#  '阿基里': <gensim.models.keyedvectors.Vocab at 0x10c49fac8>,
#  '斯腱': <gensim.models.keyedvectors.Vocab at 0x10c49fb00>,
#  '復原': <gensim.models.keyedvectors.Vocab at 0x10c49fb38>,
#  '狀況': <gensim.models.keyedvectors.Vocab at 0x10c49fb70>,
#  '可多': <gensim.models.keyedvectors.Vocab at 0x10c49fba8>,
#  '是簽': <gensim.models.keyedvectors.Vocab at 0x10c49fbe0>,
#  '臭': <gensim.models.keyedvectors.Vocab at 0x10c49fc18>,
#  '身價': <gensim.models.keyedvectors.Vocab at 0x10c49fc50>,
#  '不下': <gensim.models.keyedvectors.Vocab at 0x10c49fc88>,
#  '第二年': <gensim.models.keyedvectors.Vocab at 0x10c49fcc0>,
#  '西冠有': <gensim.models.keyedvectors.Vocab at 0x10c49fcf8>,
#  '第一年': <gensim.models.keyedvectors.Vocab at 0x10c49fd30>,
#  '還進': <gensim.models.keyedvectors.Vocab at 0x10c49fd68>,
#  '年度': <gensim.models.keyedvectors.Vocab at 0x10c49fda0>,
#  '隊伍': <gensim.models.keyedvectors.Vocab at 0x10c49fdd8>,
#  '質疑': <gensim.models.keyedvectors.Vocab at 0x10c49fe10>,
#  '版上': <gensim.models.keyedvectors.Vocab at 0x10c49fe48>,
#  '各個': <gensim.models.keyedvectors.Vocab at 0x10c49fe80>,
#  '好友': <gensim.models.keyedvectors.Vocab at 0x10c49feb8>,
#  '打過': <gensim.models.keyedvectors.Vocab at 0x10c49fef0>,
#  '看過': <gensim.models.keyedvectors.Vocab at 0x10c49ff28>,
#  '幾場': <gensim.models.keyedvectors.Vocab at 0x10c49ff60>,
#  '球': <gensim.models.keyedvectors.Vocab at 0x10c49ff98>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x10c49ffd0>,
#  '大師': <gensim.models.keyedvectors.Vocab at 0x10cff3048>,
#  '鄉': <gensim.models.keyedvectors.Vocab at 0x10cff3080>,
#  '母斯': <gensim.models.keyedvectors.Vocab at 0x10cff30b8>,
#  '自帶': <gensim.models.keyedvectors.Vocab at 0x10cff30f0>,
#  '體系': <gensim.models.keyedvectors.Vocab at 0x10cff3128>,
#  '外加': <gensim.models.keyedvectors.Vocab at 0x10cff3160>,
#  '身兼': <gensim.models.keyedvectors.Vocab at 0x10cff3198>,
#  'gm': <gensim.models.keyedvectors.Vocab at 0x10cff3208>,
#  '經濟': <gensim.models.keyedvectors.Vocab at 0x10cff3240>,
#  '送給': <gensim.models.keyedvectors.Vocab at 0x10cff3278>,
#  '波波': <gensim.models.keyedvectors.Vocab at 0x10cff32b0>,
#  '哩': <gensim.models.keyedvectors.Vocab at 0x10cff32e8>,
#  'Agg': <gensim.models.keyedvectors.Vocab at 0x10cff3358>,
#  '這季': <gensim.models.keyedvectors.Vocab at 0x10cff3390>,
#  '明顯': <gensim.models.keyedvectors.Vocab at 0x10cff33c8>,
#  '身材': <gensim.models.keyedvectors.Vocab at 0x10cff3400>,
#  '體能': <gensim.models.keyedvectors.Vocab at 0x10cff3438>,
#  '田壘': <gensim.models.keyedvectors.Vocab at 0x10cff3470>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x10cff34e0>,
#  '幹笑': <gensim.models.keyedvectors.Vocab at 0x10cff3518>,
#  '推文': <gensim.models.keyedvectors.Vocab at 0x10cff3550>,
#  '起來': <gensim.models.keyedvectors.Vocab at 0x10cff3588>,
#  '姆': <gensim.models.keyedvectors.Vocab at 0x10cff35c0>,
#  '咪': <gensim.models.keyedvectors.Vocab at 0x10cff35f8>,
#  '鍵盤': <gensim.models.keyedvectors.Vocab at 0x10cff3630>,
#  'GM': <gensim.models.keyedvectors.Vocab at 0x10cff36a0>,
#  'Lee': <gensim.models.keyedvectors.Vocab at 0x10cff3710>,
#  '這位': <gensim.models.keyedvectors.Vocab at 0x10cff3748>,
#  '沒道理': <gensim.models.keyedvectors.Vocab at 0x10cff3780>,
#  '酸酸': <gensim.models.keyedvectors.Vocab at 0x10cff37b8>,
#  '說說看': <gensim.models.keyedvectors.Vocab at 0x10cff37f0>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x10cff3828>,
#  '崩': <gensim.models.keyedvectors.Vocab at 0x10cff3860>,
#  '好多': <gensim.models.keyedvectors.Vocab at 0x10cff3898>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x10cff38d0>,
#  '嫌': <gensim.models.keyedvectors.Vocab at 0x10cff3908>,
#  '臭頭': <gensim.models.keyedvectors.Vocab at 0x10cff3940>,
#  '無視': <gensim.models.keyedvectors.Vocab at 0x10cff3978>,
#  ...}

# %%
query_str = "舒適"
print("相似詞前 100 排序")
res = model.most_similar(query_str,topn = 100)
for item in res:
    print(item[0]+","+str(item[1]))
# Out:
# /Users/coslate/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 2018-06-07 22:54:05,908 : INFO : precomputing L2-norms of word weight vectors
# 相似詞前 100 排序
# 大團,0.7972372770309448
# 恐怖,0.7578041553497314
# 粗,0.7493706941604614
# 刺激,0.7424580454826355
# 聰明,0.7147158980369568
# 大團還,0.7068061828613281
# 穩,0.7050856351852417
# 低調,0.6940222978591919
# 無恥,0.6896555423736572
# 多冠,0.6890169978141785
# 沒品,0.6879103183746338
# 過份,0.6866902112960815
# 武斷,0.6844911575317383
# 反常,0.6828036308288574
# 兇,0.6748685836791992
# 糟糕,0.6715617775917053
# 殘忍,0.6711763143539429
# 可怕,0.6685829162597656
# 囂張,0.6574757695198059
# 自私,0.65742027759552
# 有用,0.6552450060844421
# 別提,0.6546655297279358
# 弱,0.6525865793228149
# 要緊,0.650679886341095
# 爛吧,0.6503111720085144
# 激烈,0.6501925587654114
# 謎,0.6500975489616394
# 乾淨,0.6498275995254517
# 公道,0.6476929187774658
# 加把勁,0.6463181972503662
# 有錢,0.6455506682395935
# 噁,0.645093560218811
# 圈,0.6444162726402283
# 划算,0.6425272822380066
# 棒,0.6415302753448486
# 好找,0.6403617858886719
# 不切實際,0.6403000354766846
# 厲害,0.6399767398834229
# 可笑,0.6396691799163818
# 誠實,0.6392339468002319
# 牛仔,0.636186420917511
# 感人,0.6323307156562805
# 激動,0.632219135761261
# 廢,0.6320824027061462
# 殘酷,0.6308598518371582
# 惡劣,0.6295284032821655
# 乖,0.6288514733314514
# 謙虛,0.6281355619430542
# 值錢,0.6267930865287781
# 艱難,0.6261661648750305
# 水,0.6243524551391602
# 樂觀,0.6236644983291626
# 多場,0.6226262450218201
# 貪心,0.622546374797821
# 客氣,0.6171377301216125
# 年輕人,0.6156803965568542
# 好玩,0.6156069040298462
# 悲觀,0.6148282289505005
# 難搞,0.6139367818832397
# 痛,0.6137122511863708
# 笨重,0.6130474805831909
# 大張,0.6128660440444946
# 脆弱,0.612480103969574
# 牽強,0.6118203997612
# 瞎,0.6114078164100647
# 搶眼,0.6104046702384949
# 難看,0.6098605990409851
# 辛苦,0.609460175037384
# 頭痛,0.6071251034736633
# 難守,0.6068446636199951
# 噁心,0.6063975095748901
# 玻璃,0.6060541272163391
# 不堪,0.6055461764335632
# 強阿,0.6045286059379578
# 誇張,0.6037560105323792
# 單調,0.6035236120223999
# 貴,0.603506326675415
# 別說,0.6033533215522766
# 白,0.600879430770874
# 熱血,0.6005237102508545
# 高調,0.5999700427055359
# 無聊,0.599746584892273
# 差是,0.5993495583534241
# 有品,0.5982123017311096
# 久,0.5981614589691162
# 高尚,0.5977482795715332
# 丟臉,0.5971256494522095
# 篤定,0.5971082448959351
# 複雜,0.5966346859931946
# 大聲,0.5956331491470337
# 有戲,0.5953218936920166
# 難纏,0.5947080850601196
# 可恥,0.5944716334342957
# 口憐,0.5933010578155518
# 舒服,0.5932347774505615
# 謹慎,0.5925429463386536
# 逗趣,0.5924529433250427
# 合理,0.5920085906982422
# 戰積,0.5911096334457397
# 令人感動,0.5909462571144104

# %%
#%run -i /Users/coslate/Word2Vec/Preprocess/preprocess.py

# %%
query_str = "坦"
print("相似詞前 100 排序")
res = model.most_similar(query_str,topn = 100)
for item in res:
    print(item[0]+","+str(item[1]))
# Out:
# 相似詞前 100 排序
# 練兵,0.7829620838165283
# 待,0.705497145652771
# 重建,0.6810632348060608
# 輪休,0.6598561406135559
# 拉,0.6556564569473267
# 擺爛,0.6548957824707031
# 退,0.646939754486084
# 贏了,0.6457115411758423
# 玩,0.6429154872894287
# 要坦,0.6405560374259949
# 磨合,0.6361189484596252
# 休息,0.6313775181770325
# 反正,0.631178081035614
# 搞,0.6290395259857178
# 暑假,0.6264240741729736
# 排,0.6207107901573181
# 養,0.6198354363441467
# 擺明,0.6189054250717163
# 不然,0.6158210635185242
# 拼,0.6143950819969177
# 賭,0.6141297817230225
# 走,0.6138303875923157
# 要贏,0.6132808327674866
# 變爛,0.6100177764892578
# 以後,0.6061175465583801
# 停,0.6014876365661621
# 轉隊,0.5990915298461914
# 贏的,0.5982894897460938
# 輸球,0.5966237187385559
# 追,0.5941500067710876
# 凹,0.5938486456871033
# 不知,0.5911413431167603
# 放掉,0.5894707441329956
# 休,0.5854532122612
# 拿出,0.5843186378479004
# 輸,0.582913339138031
# 捧,0.5814993381500244
# 掰,0.5805394053459167
# 喊,0.5791733860969543
# 說不定,0.5779862403869629
# 拚,0.5777896046638489
# 怪,0.5774351954460144
# 酸,0.5759246945381165
# 提,0.5754292607307434
# 放棄,0.5753893852233887
# 拿冠,0.5750840306282043
# 道歉,0.5727255344390869
# 開,0.5721076726913452
# 做,0.571599543094635
# 出現,0.5714287757873535
# 碰,0.5697651505470276
# 頂薪,0.5697465538978577
# 贏,0.5672170519828796
# 奪冠,0.5657105445861816
# 贏球,0.5642837882041931
# 挑,0.563526451587677
# 過去,0.5629391670227051
# 會輸,0.562414824962616
# 跳,0.5614586472511292
# 過了,0.5599849224090576
# 打工,0.557628870010376
# 傷,0.5574894547462463
# 爭,0.5574853420257568
# 否則,0.557195246219635
# 該,0.5553421378135681
# 檢討,0.555327832698822
# 講,0.5546638369560242
# 搞不好,0.5532042384147644
# 當一哥,0.5522134304046631
# 嘛,0.5518398880958557
# 整隊,0.5506912469863892
# 傷兵,0.5502196550369263
# 偷笑,0.5500690340995789
# 練,0.5499113202095032
# 扯,0.5496031045913696
# 一天,0.5480121970176697
# 救,0.5472403168678284
# 談,0.5466206669807434
# 現在,0.5457066893577576
# 罵,0.545279860496521
# 賺,0.5444352030754089
# 留,0.5444332957267761
# 忘記,0.5432214140892029
# 明年,0.5428116917610168
# 改,0.542076826095581
# 呀,0.5415392518043518
# 處理,0.5402593612670898
# 洗白,0.5401729941368103
# 所以,0.5398150086402893
# 換人,0.539086103439331
# 諾貝爾獎,0.5381887555122375
# 討論,0.5380741953849792
# 證明,0.5375077724456787
# 白,0.5370273590087891
# 解散,0.5363625884056091
# 亂打,0.5357989072799683
# 練球,0.5355719327926636
# 連敗,0.5355282425880432
# 選到,0.5352898240089417
# 補強,0.5338030457496643
# /Users/coslate/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
query_str = "馬刺"
print("相似詞前 100 排序")
res = model.most_similar(query_str,topn = 100)
for item in res:
    print(item[0]+","+str(item[1]))
# Out:
# /Users/coslate/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 相似詞前 100 排序
# 他們,0.6258862018585205
# MDA,0.6144922375679016
# 賽隊,0.5947726368904114
# 對手,0.590988039970398
# 健康,0.5861596465110779
# 坦隊,0.5745985507965088
# 奪冠,0.5673978328704834
# 強隊,0.5649535059928894
# 狀況,0.5578109622001648
# 季賽,0.5558617115020752
# 剛好,0.5533828139305115
# 西區,0.5467138290405273
# 贏球,0.5462924242019653
# 波波,0.542401909828186
# 拼,0.5398615598678589
# 姆斯,0.5347954630851746
# 原本,0.5314815044403076
# 沒差,0.525274395942688
# 戰績,0.5248744487762451
# 輪休,0.5225514769554138
# 看來,0.521894097328186
# 季後賽,0.5204556584358215
# 刺,0.5140124559402466
# 刺刺,0.5135536193847656
# 保持,0.5124526619911194
# 氣勢,0.5112959146499634
# 我們,0.5105915069580078
# 成功,0.510098934173584
# 可愛,0.5085472464561462
# 西冠,0.5084190368652344
# 陣容,0.508113443851471
# 輕鬆,0.5075623393058777
# 賽,0.5063917636871338
# 接下來,0.5040674805641174
# 第一輪,0.4978235065937042
# 復出,0.49682289361953735
# 三軍,0.4962562620639801
# 大歐,0.496080607175827
# 聯盟,0.4938748776912689
# 重建,0.4937198758125305
# 全部,0.49216213822364807
# 贏了,0.4907446503639221
# 爭冠,0.49026069045066833
# 哈登,0.4900168180465698
# 之後,0.4899149239063263
# 實力,0.48876476287841797
# 輸贏,0.488268107175827
# 狀態,0.48717397451400757
# 總冠,0.48681479692459106
# 內,0.48485279083251953
# 第二輪,0.4848036766052246
# 今年,0.48385730385780334
# 系列賽,0.4829791784286499
# 練兵,0.48235148191452026
# 對面,0.48032188415527344
# 拚,0.48026058077812195
# 四場,0.4801315665245056
# 放棄,0.4789574146270752
# 青賽,0.47883129119873047
# 優勢,0.47879520058631897
# 輸,0.47826969623565674
# 東區,0.4768165349960327
# 補強,0.47662222385406494
# 馬刺隊,0.47648805379867554
# AGG,0.47634178400039673
# 兩隊,0.476113885641098
# 三連霸,0.4754756987094879
# 橫掃,0.4754435420036316
# TD,0.47432923316955566
# 拿冠,0.4742371737957001
# ，,0.4740152657032013
# 傷兵,0.47305312752723694
# 半,0.4711419939994812
# 幾乎,0.4710875153541565
# 他,0.47085094451904297
# 第四節,0.4706266522407532
# 後面,0.4705961048603058
# 戰力,0.46966925263404846
# 湖人會贏,0.46955054998397827
# 鬍子,0.46834537386894226
# 紀錄,0.4679143726825714
# 選秀,0.466728150844574
# 瓜,0.4659074544906616
# 開季,0.4652418792247772
# 坦,0.4644443988800049
# 情況,0.46381744742393494
# 二,0.4622038006782532
# 就算,0.4612152576446533
# 巫師,0.4608306586742401
# 主力,0.46039509773254395
# 不過,0.4602864384651184
# 若,0.46023377776145935
# Nash,0.459939569234848
# 如果,0.45977967977523804
# 畢竟,0.45921438932418823
# 西決,0.4591013491153717
# 賽程,0.458430677652359
# 說不定,0.4567723870277405
# LBJ,0.45665881037712097
# 哪隊,0.45654764771461487

# %%
query_str = "LBJ"
print("相似詞前 100 排序")
res = model.most_similar(query_str,topn = 100)
for item in res:
    print(item[0]+","+str(item[1]))
# Out:
# 相似詞前 100 排序
# lbj,0.8586726188659668
# 姆斯,0.8311863541603088
# KD,0.8063055872917175
# kd,0.8051726818084717
# MJ,0.7873992919921875
# KI,0.781137228012085
# 喇叭,0.7619571685791016
# 喬丹,0.7523543834686279
# 老大,0.7499502897262573
# cp3,0.7494181394577026
# kobe,0.7468443512916565
# 馬龍,0.7347446084022522
# TD,0.7325296401977539
# 組團,0.7285680174827576
# KOBE,0.7257248759269714
# Kobe,0.7147107720375061
# 降薪,0.7127783298492432
# 轉隊,0.7121899724006653
# wade,0.7121250033378601
# CP3,0.7098884582519531
# 三王,0.7093657851219177
# 甜瓜,0.700842022895813
# 副手,0.700276255607605
# 西河,0.6990874409675598
# 鬍子,0.6808655858039856
# 雜魚,0.6744633913040161
# KB,0.6664379835128784
# 大歐,0.6601099371910095
# 奪冠,0.6594093441963196
# 組隊,0.6585395336151123
# 單核,0.65701824426651
# 咖哩,0.6563167572021484
# 抱團,0.6538300514221191
# KL,0.6496938467025757
# 歐肥,0.6490073204040527
# Wade,0.6451190710067749
# td,0.6419118642807007
# mj,0.6416588425636292
# AD,0.6413612961769104
# 大羅,0.6407932639122009
# CURRY,0.6406562328338623
# 三連霸,0.6400481462478638
# PG,0.6383056044578552
# 小蟲,0.6376553773880005
# 強隊,0.6370720267295837
# 巔峰,0.6335757970809937
# curry,0.6334041953086853
# Curry,0.6272905468940735
# KT,0.626754105091095
# Bosh,0.6185020804405212
# 球星,0.6149237155914307
# 禪師,0.6148527264595032
# nash,0.6141259670257568
# IT,0.6136425137519836
# 坦隊,0.6119170784950256
# 其他人,0.6077255010604858
# 現在,0.6045510768890381
# FMVP,0.6025430560112
# 加入,0.6021466851234436
# KG,0.6020047068595886
# 表弟,0.6018240451812744
# ki,0.6015294194221497
# 當初,0.6014211773872375
# KP,0.6009611487388611
# 一哥,0.5986920595169067
# 哈登,0.5983895063400269
# 當年,0.5981875061988831
# Nash,0.5981616377830505
# 沒冠,0.5969269275665283
# MDA,0.5963340401649475
# Shaq,0.5941728949546814
# 母獅,0.5933734774589539
# 老巴,0.5926651358604431
# 王朝,0.5918047428131104
# 阿罵,0.5915810465812683
# 路人,0.5914976000785828
# 爭冠,0.590076208114624
# 東區,0.5878127217292786
# RJ,0.5866801142692566
# 打不贏,0.5847934484481812
# LOVE,0.5841898918151855
# 一冠,0.5841349363327026
# 腿,0.583724319934845
# 更強,0.58145672082901
# 報團,0.5807929039001465
# melo,0.5804375410079956
# POPO,0.5786311030387878
# 以後,0.5768358111381531
# 喬治,0.576117217540741
# 歐拉,0.5753577947616577
# 隊伍,0.5748763084411621
# 同隊,0.5701735019683838
# 綠葉,0.5699588060379028
# JR,0.5672011971473694
# BG,0.5647088289260864
# 基石,0.5645850300788879
# 擺爛,0.5639938712120056
# 抱,0.5614023208618164
# 冠軍,0.5597006678581238
# 全明星,0.5592225790023804
# /Users/coslate/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
